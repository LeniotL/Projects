# %% [markdown]
# # <span style="font-family: 'Brush Script MT'; font-size: 100px; color: rgba(255, 0, 0, 0.7)">Capstone Project</span>

# %% [markdown]
# <div style="text-align: center; font-family: 'Comic Sans MS'; font-size: 40px; color: rgb(1, 77, 78); font-style: italic;">Restaurant Recommender System</div>

# %% [markdown]
# <div style="text-align: right; font-family: 'Comic Sans MS'; color: rgba(255, 0, 0, 0.7)"">By Lim Zi Ming</div>

# %% [markdown]
# ![](images/tokyo_city.jpg)

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import pickle
import h5py
from streamlit_lottie import st_lottie
import json
import os
import requests
from tqdm.notebook import tqdm
from google.cloud import translate_v2 as translate

# %% [markdown]
# ## Importing Datas

# %%
# Load the cleaned restaurant dataset
restaurants = pd.read_pickle('data/restaurants_cleaned.pkl')

# %%
restaurants = restaurants.sort_values(by='rating_val', ascending=False)
restaurants
# Out:
#        store_id             name nearest_station  nearest_distance  \
# 10600  13018162       日本橋蛎殻町 すぎた           水天宮前駅             105.0
# 18145  13136847           新ばし 星野            御成門駅             412.0
# 14202  13124391               松川         六本木一丁目駅             414.0
# 20709  13196420           東麻布 天本            赤羽橋駅             258.0
# 12301  13249117               アカ            三越前駅             146.0
# ...         ...              ...             ...               ...
# 35823  13016768              蓮玉庵          上野御徒町駅             171.0
# 58787  13166438         ネパリコ 駒沢店           駒沢大学駅             172.0
# 15206  13155192  イタリアンダイニング ジリオン             竹芝駅              87.0
# 72034  13094042            定食サトウ             神泉駅             105.0
# 33829  13257871   貝出汁らぁ麺 海美風 浅草店     浅草（つくばＥＸＰ）駅             154.0
#
#                                      genre  rating_val  review_cnt  save_cnt  \
# 10600                       寿司                    4.71       629.0   76295.0
# 18145                     日本料理                    4.63       193.0   19869.0
# 14202                     日本料理                    4.63       396.0   44049.0
# 20709                       寿司                    4.61       423.0   42946.0
# 12301         スペイン料理、モダンスパニッシュ                    4.61       263.0   32951.0
# ...                                    ...         ...         ...       ...
# 35823                       そば                    3.46       124.0    5291.0
# 58787  ネパール料理、ダイニングバー、カレー（その他）                    3.46       102.0    5130.0
# 15206                    イタリアン                    3.46       119.0    3825.0
# 72034                    定食・食堂                    3.46        82.0    9546.0
# 33829                     ラーメン                    3.46       111.0    1676.0
#
#       budget_dinner budget_lunch                             address  \
# 10600     expensive    expensive    東京都中央区日本橋蛎殻町1-33-6 ビューハイツ日本橋 B1F
# 18145     expensive      unknown                       東京都港区新橋5-31-3
# 14202     expensive    expensive           東京都港区赤坂1-11-6 赤坂テラスハウス １階
# 20709     expensive      unknown            東京都港区東麻布1-7-9 ザ・ソノビル 102
# 12301     expensive    expensive              東京都中央区日本橋室町2-1-1 三井2号館
# ...             ...          ...                                 ...
# 35823       unknown        cheap                       東京都台東区上野2-8-7
# 58787       average        cheap          東京都世田谷区上馬4-2-6 サンシティー東和101
# 15206     expensive      average  東京都港区海岸1-16-2 ホテル インターコンチネンタル 東京ベイ
# 72034         cheap        cheap             東京都渋谷区円山町13-9 メゾン若林 B1F
# 33829         cheap        cheap          東京都台東区浅草2-13-3 ディアレスト浅草 1F
#
#       municipalities_1 municipalities_2
# 10600              中央区           日本橋蛎殻町
# 18145               港区               新橋
# 14202               港区               赤坂
# 20709               港区              東麻布
# 12301              中央区            日本橋室町
# ...                ...              ...
# 35823              台東区               上野
# 58787             世田谷区               上馬
# 15206               港区               海岸
# 72034              渋谷区              円山町
# 33829              台東区               浅草
#
# [10000 rows x 13 columns]

# %% [markdown]
# We are prioritizing restaurants based on their ratings because our primary goal is to recommend the best dining experiences to users. High ratings typically indicate positive customer experiences, ensuring that our recommendations are top-notch and reliable.

# %% [markdown]
# ## Model Run

# %% [markdown]
# **1. Feature Selection and Processing:**  <u>(Take note that the translation cells have been changed to raw cells to prevent surpassing the permitted usage thresholds of the translation API.)</u>

# %% [markdown]
# **Feature Selection**:
# In the dataset containing information about various restaurants, we have selected a subset of relevant features that are crucial for our analysis. The chosen columns are:
# - `name`: The name of the restaurant.
# - `genre`: The type or genre of food the restaurant serves (e.g., Japanese, Chinese, Italian).
# - `rating_val`: The rating value of the restaurant, indicating its quality and customer satisfaction.
# - `nearest_station`: The closest train or subway station to the restaurant, indicating its accessibility.
# - `address`: The complete address of the restaurant, helping identify its exact location.

# %% [raw]
# restaurants = restaurants[['name', 'genre', 'rating_val', 'nearest_station', 'address']]

# %% [markdown]
# **Data Processing with Google Cloud Translation AI**: Considering that we are harnessing restaurant reviews from Japanese locals, it's essential to make this valuable information accessible to foreign users visiting Japan. Given that  the data is in Japanese, we've leveraged the Google Cloud Translation AI to translate it into English, ensuring both clarity and broader accessibility for our international audience. `address` will be kept in japanese to prevent any misinformation after translating to english, ensuring that the data remains accurate.

# %% [markdown]
# **Initialization**: Set up the Google Cloud environment and initialize the translation client.

# %%
#pip install --upgrade google-cloud-translate

# %% [raw]
# # Set the path to the service account key
# os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = '. . .' # Replace with own service account key
#
# translate_client = translate.Client()

# %% [markdown]
# **Translation Function**:
# A function, `google_translate`, is defined to seamlessly convert Japanese text into English using the Google Cloud Translation API.

# %% [raw]
# def google_translate(text, target_language='en'):
#     if pd.isnull(text):
#         return text
#     result = translate_client.translate(text, target_language=target_language)
#     return result['translatedText']

# %% [markdown]
# **Chunk-Based Data Translation using Google Cloud Translation API**:
#
# Given the vastness of our dataset, translating every row in a single request is neither feasible nor efficient. We adopt a **chunk-based translation approach**, enhancing manageability and effectiveness. We segment our data into chunks, each containing approximately `100` rows. The dataset is efficiently and systematically translated using a chunked approach, aiding in progress tracking and resource management.

# %% [raw]
# # Define the chunk size
# chunk_size = 100
#
# # Split the DataFrame into chunks
# chunks = np.array_split(restaurants, len(restaurants) // chunk_size + 1)
#
# # List to collect translated chunks
# translated_chunks = []
#
# # Main tqdm progress bar for chunks
# for idx, chunk in tqdm(enumerate(chunks), desc="Processing chunks"):
#     # Nested tqdm progress bar for columns within each chunk
#     for column in tqdm(['name', 'genre', 'nearest_station'], desc=f"Translating columns for chunk {idx+1}/{len(chunks)}", leave=False):
#         chunk[column] = chunk[column].apply(google_translate)
#     translated_chunks.append(chunk)
#
# # Concatenate all chunks back to a single DataFrame
# translated_restaurants = pd.concat(translated_chunks)

# %% [markdown]
# **Further Cleaning Process**:
# 1. **Lowercasing Columns:** The `name`, `genre`, and `nearest_station` columns of the `translated_restaurants` dataframe have been converted to lowercase.
# 2. **Row Filtering:** After identifying some anomalies on the translated restaurant names, any rows where the `name` column contains the characters `%`, `#`, or `;` will be removed for data consistency and clarity.

# %% [raw]
# # Convert the columns to lowercase
# translated_restaurants['name'] = translated_restaurants['name'].str.lower()
# translated_restaurants['genre'] = translated_restaurants['genre'].str.lower()
# translated_restaurants['nearest_station'] = translated_restaurants['nearest_station'].str.lower()
#
# # Remove rows where 'name' column contains %, # or ;
# translated_restaurants = translated_restaurants[~translated_restaurants['name'].str.contains('[%#;]', na=False)]

# %% [raw]
# # Save the results to a CSV file
# translated_restaurants.to_csv("data/translated_restaurants.csv", index=False)

# %%
restaurants = pd.read_csv('data/translated_restaurants.csv')

# %%
restaurants
# Out:
#                                       name  \
# 0             nihonbashi kakigaracho suita
# 1                        shinbashi hoshino
# 2                                matsukawa
# 3                     higashiazabu amamoto
# 4                                      red
# ...                                    ...
# 9995                            tamoiyanse
# 9996                               la vita
# 9997                    professional super
# 9998                   bambi yotsuya store
# 9999  beef beef sushi x shabu yakiniku 2+9
#
#                                                  genre  rating_val  \
# 0                                                sushi        4.71
# 1                                        japanese food        4.63
# 2                                        japanese food        4.63
# 3                                                sushi        4.61
# 4                      spanish cuisine, modern spanish        4.61
# ...                                                ...         ...
# 9995  local cuisine (others), chicken dishes, mizutaki        3.46
# 9996                                           italian        3.46
# 9997                                              cake        3.46
# 9998                    western food, steak, hamburger        3.46
# 9999                         yakiniku, offal, barbecue        3.46
#
#                nearest_station                           address
# 0          suitengumae station  東京都中央区日本橋蛎殻町1-33-6 ビューハイツ日本橋 B1F
# 1             onarimon station                     東京都港区新橋5-31-3
# 2     roppongi itchome station         東京都港区赤坂1-11-6 赤坂テラスハウス １階
# 3         akabanebashi station          東京都港区東麻布1-7-9 ザ・ソノビル 102
# 4        mitsukoshimae station            東京都中央区日本橋室町2-1-1 三井2号館
# ...                        ...                               ...
# 9995           shinsen station             東京都渋谷区神泉町10-10 神泉ビル1F
# 9996  yotsuya sanchome station             東京都新宿区四谷3-4-9 臼井ビル　１Ｆ
# 9997     nakamurabashi station                   東京都練馬区中村北4-8-30
# 9998           yotsuya station               東京都新宿区四谷1-3 津嶋ビル 1F
# 9999            daimon station          東京都港区浜松町1-18-11 MSビル1・2F
#
# [10000 rows x 5 columns]

# %% [markdown]
# **2. Genre Processing:**
# - Each restaurant can have multiple genres which are separated by the '、' character. These genres are split and flattened to create a list of unique genre values.
# - The frequency of each genre in the dataset is computed.

# %%
# Split genres, remove spaces, flatten the genre list, and get unique genre values
genres = restaurants['genre'].str.split(',').explode().str.strip().value_counts()

# %% [markdown]
# **3. One-hot Encoding:**
# - To facilitate the recommendation process, genres are one-hot encoded. This means for each genre, a new column is added to the dataframe. If a restaurant belongs to that genre, it will have a '1' in the corresponding column, otherwise '0'.
# - These one-hot encoded genre columns are then added back to the main `restaurants` dataframe.

# %%
# One-hot encode the genres
genre_dfs = []
for genre in genres.index:
    genre_df = restaurants['genre'].str.contains(genre, regex=False).astype(int).rename(genre)
    genre_dfs.append(genre_df)   

# Merge the one-hot encoded genre DataFrames with the original dataframe
genres_df = pd.concat(genre_dfs, axis=1)
restaurants = pd.concat([restaurants, genres_df], axis=1)

# %%
genres_df.to_csv("data/genres_df.csv", index=False)

# %% [markdown]
# **4. Cosine Similarity:**
# Based on the genre features, the cosine similarity between each pair of restaurants is computed. This similarity gives a measure of how alike two restaurants are in terms of their genres.

# %%
# Compute Cosine Similarity based on genre features
cosine_sim = cosine_similarity(genres_df)

# %% [markdown]
# **5. Recommendation Function:**
# A function named `recommend_by_genre` is defined to recommend restaurants based on selected genres and, optionally, the nearest station. Here's how it works:
# - The function first checks if the input genres exist in the dataset.
# - A genre vector is created, which is a combination of all selected genres. This vector is normalized and reshaped.
# - The cosine similarity scores for this genre vector against all restaurants are calculated. Setting 0.3 to yield recommendations with similarity score above 30%.
# - Based on the similarity scores, the top restaurants are selected. If a nearest station is provided, the list is filtered to include only restaurants near that station.
# - Finally, the top 10 restaurants are returned, sorted by their ratings.

# %%
# Function to recommend restaurants based on selected genres and optionally, a nearest station
def recommend_by_genre(input_genres, nearest_station=None, cosine_sim=cosine_sim, min_similarity=0.3):
    # Check if all selected genres exist in the dataset
    for genre in input_genres:
        if genre not in genres_df.columns:
            return f"Genre {genre} not found in the dataset"

    # Create a combined genre vector for all selected genres
    genre_vector = np.zeros(genres_df.shape[1])
    for genre in input_genres:
        genre_index = list(genres_df.columns).index(genre)
        genre_vector[genre_index] = 1

    # Normalize the genre vector and reshape
    genre_vector /= len(input_genres)
    genre_vector = genre_vector.reshape(1, -1)

    # Compute the cosine similarity scores for the genre vector against all restaurants
    sim_scores = cosine_similarity(genre_vector, genres_df.values)
    sim_scores = [x for x in enumerate(sim_scores[0]) if x[1] >= min_similarity]
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # If a station is selected, filter by that station
    if nearest_station:
        station_filtered_indices = [i[0] for i in sim_scores if restaurants.iloc[i[0]]['nearest_station'] == nearest_station]
        top_10_indices = station_filtered_indices[:10]
    else:
        top_10_indices = [i[0] for i in sim_scores[:10]]

    # Get the top 10 restaurants and sort them by rating
    top_10_restaurants = restaurants.iloc[top_10_indices]
    sorted_restaurants = top_10_restaurants.sort_values(by='rating_val', ascending=False)
    return sorted_restaurants[['name', 'rating_val', 'nearest_station']]

# %% [markdown]
# This process provides a robust mechanism to recommend restaurants based on user's genre preferences and their proximity to a particular station.
#
# ---

# %% [markdown]
# Displying all the genres and train stations available for the recommender system.

# %%
# Adjust display settings
pd.set_option('display.max_rows', None)

restaurants['genre'].str.split(',').explode().str.strip().value_counts()
# Out:
# ramen                                           1469
# izakaya                                         1361
# cafe                                             860
# italian                                          704
# tsukemen                                         673
# french                                           537
# japanese cuisine                                 496
# wine bar                                         438
# sushi                                            424
# bread                                            418
# soba                                             401
# bistro                                           371
# cake                                             358
# seafood dishes                                   342
# curry rice                                       337
# yakiniku                                         335
# chinese food                                     333
# yakitori                                         304
# western food                                     301
# dining bar                                       295
# pasta                                            290
# steak                                            268
# coffee shop                                      247
# udon                                             229
# indian curry                                     229
# japanese food                                    227
# seafood/seafood dishes                           225
# bar                                              214
# tempura                                          207
# chinese cuisine                                  192
# sake bar                                         175
# japanese food (other)                            170
# japanese sweets                                  166
# gyoza                                            163
# hamburger                                        157
# pizza                                            156
# chicken dishes                                   145
# eel                                              138
# dandan noodles                                   124
# bar bar                                          122
# teppanyaki                                       113
# sandwich                                         111
# pork cutlet                                      109
# thai food                                        107
# modern french                                    107
# creative cuisine                                 106
# indian food                                      102
# korean food                                      101
# offal                                             96
# motsuyaki                                         95
# coffee specialty store                            94
# abura soba                                        94
# shaved ice                                        93
# set meal/dining room                              93
# western sweets (other)                            89
# horumon                                           87
# curry (other)                                     82
# innovative fusion                                 82
# chinese noodles (other)                           81
# beer bar                                          80
# tonkatsu                                          80
# sichuan cuisine                                   78
# shabu-shabu                                       78
# thai curry                                        77
# cakes                                             75
# sandwiches                                        72
# sweets (other)                                    70
# yakiton                                           68
# seafood dishes/seafood dishes                     68
# chocolate                                         67
# japanese food (others)                            67
# set meals/dining room                             66
# ice cream                                         63
# sweets shop                                       62
# grilled meat                                      58
# indian cuisine                                    58
# sukiyaki                                          58
# western cuisine (other)                           57
# japanese sake bar                                 57
# cafe/coffee shop (other)                          56
# local cuisine (other)                             55
# seafood                                           54
# oden                                              50
# pancakes                                          50
# dim sum/dim sum                                   50
# okonomiyaki                                       49
# lounge                                            47
# tendon/tenju                                      46
# spanish cuisine                                   45
# buffet                                            42
# standing izakaya/bar                              42
# beef dishes                                       42
# omelet rice                                       41
# dumplings                                         41
# curry udon                                        41
# bento                                             41
# parfait                                           39
# bread/sandwiches (other)                          38
# asian/ethnic cuisine (other)                      37
# sweets (others)                                   37
# delicatessen                                      36
# hormone                                           36
# dorayaki                                          35
# hamburgers                                        35
# grilled chicken                                   35
# seafood bowl                                      34
# curry (others)                                    34
# cantonese cuisine                                 34
# izakaya/dining bar (other)                        34
# bar/alcohol (other)                               32
# hot pot (other)                                   32
# pancake                                           31
# cafes                                             31
# soup curry                                        31
# oyakodon                                          30
# chinese noodles (others)                          30
# daifuku                                           30
# european curry                                    30
# standing soba                                     29
# hot pot (others)                                  29
# fugu                                              28
# genghis khan                                      28
# rice bowls (other)                                28
# vegetable dishes                                  28
# shanghai cuisine                                  28
# katsudon/katsuju                                  28
# restaurant (other)                                27
# kushiage                                          27
# bar/bar                                           27
# western confectionery (other)                     26
# soupless dandan noodles                           26
# hotpot (other)                                    26
# hamburger steak                                   26
# crab                                              25
# loach                                             25
# nepali food                                       24
# croquettes/fries                                  24
# shochu bar                                        24
# mizutaki                                          24
# taiwanese cuisine                                 24
# katsudon                                          23
# western sweets (others)                           23
# beef tongue                                       23
# katsuju                                           23
# confectionery (others)                            23
# vietnamese food                                   23
# charcoal grill                                    22
# dim sum                                           22
# monjayaki                                         22
# set meals/restaurants                             22
# oyster bar                                        22
# local cuisine (others)                            22
# cold noodles                                      21
# natural food                                      21
# curry and rice                                    21
# dandan noodles without soup                       20
# fried food                                        20
# japanese cuisine (other)                          20
# skewers                                           20
# fruit parlor                                      20
# western/european cuisine (other)                  19
# hayashi rice                                      19
# izakaya/dining bar (others)                       19
# stew                                              19
# taiyaki/obanyaki                                  19
# bagel                                             19
# standing sushi                                    18
# conveyor belt sushi                               18
# set meals                                         18
# tavern                                            18
# bagels                                            18
# tea and snacks                                    17
# bars                                              17
# burgers                                           17
# korean hotpot                                     17
# hormones                                          17
# japanese tea specialty store                      16
# soft serve ice cream                              16
# yakisoba                                          16
# spanish                                           16
# korean cuisine                                    16
# modern spanish                                    16
# champon                                           16
# tachinomi izakaya/bar                             16
# standing eating soba                              16
# cantonese food                                    16
# tenju                                             16
# motsunabe                                         15
# croquette fries                                   15
# crepe                                             15
# blowfish                                          15
# yum cha・dim sum                                   15
# tea specialty store                               15
# set meals/diners                                  15
# beijing cuisine                                   14
# horse meat dishes                                 14
# beer hall/beer restaurant                         14
# conger eel                                        14
# juice bar                                         14
# yum cha                                           14
# soft-shelled turtle                               14
# seafood and seafood                               13
# standing bar/bar                                  13
# kushiyaki                                         13
# tendon                                            13
# nepali cuisine                                    13
# thai cuisine                                      13
# rice balls                                        13
# pork dishes                                       12
# confectionery (other)                             12
# robatayaki                                        12
# pubs                                              12
# sichuan food                                      12
# donuts                                            12
# chinese                                           12
# stand-up soba                                     12
# sweets parlor                                     12
# other meat dishes                                 11
# omurice                                           11
# macaron                                           11
# asian and ethnic cuisine (others)                 11
# asian/ethnic food (other)                         11
# seafood cuisine                                   11
# french toast                                      11
# asian/ethnic cuisine (others)                     11
# sri lankan cuisine                                11
# oil soba                                          11
# hamburg steak                                     11
# american food                                     10
# chinese pot・hot pot                               10
# kamameshi                                         10
# taiwanese mazesoba                                10
# macarons                                          10
# lunch box                                         10
# samgyeopsal                                       10
# western/european cuisine (others)                 10
# baumkuchen                                        10
# japanese confectionery                            10
# mexican food                                       9
# latin american cuisine (other)                     9
# sweet shop                                         9
# turkish cuisine                                    9
# chinese hotpot/hotpot                              9
# pakistani food                                     9
# japanese dishes                                    9
# medicinal dishes                                   9
# cafes (others)                                     9
# russian food                                       9
# singaporean cuisine                                9
# okinawan cuisine                                   9
# donburi (others)                                   9
# bread/sandwich (other)                             9
# vietnamese cuisine                                 9
# mediterranean                                      9
# bakery                                             9
# rice bowl (other)                                  8
# deep-fried skewers                                 8
# croquette/fries                                    8
# liquor (others)                                    8
# southeast asian cuisine (others)                   8
# fried chicken                                      8
# desserts                                           8
# viking                                             8
# japanese                                           8
# rice bowls (others)                                8
# mediterranean cuisine                              8
# taiwanese food                                     8
# american                                           8
# beer garden                                        8
# chanko nabe                                        8
# hot pot                                            8
# nepalese cuisine                                   8
# tea and dim sum                                    8
# fried noodles                                      7
# xiaolongbao                                        7
# rice crackers                                      7
# shanghai food                                      7
# western cuisine (others)                           7
# west asian cuisine (other)                         7
# japanese sweets shop                               7
# offal hotpot                                       7
# seafood/seafood                                    7
# japanese (others)                                  7
# beef                                               7
# beer bars                                          7
# european-style curry                               7
# dumpling                                           7
# japanese (other)                                   7
# coffee specialty shop                              7
# japanese sake bars                                 7
# american cuisine                                   7
# cafeteria                                          7
# whale dishes                                       7
# chocolates                                         6
# noodles (others)                                   6
# restaurants (other)                                6
# charcoal-grilled                                   6
# korean hot pot                                     6
# chinese pot/hot pot                                6
# south asian cuisine (other)                        6
# cafeterias                                         6
# asian/ethnic food (others)                         6
# creative dishes                                    6
# pork shabu-shabu                                   6
# soba/udon/noodles (other)                          6
# western confectionery (others)                     6
# churrasco                                          6
# fried foods                                        6
# set meal                                           6
# soft serve                                         6
# offal dishes                                       6
# beef bowl                                          6
# lounges                                            6
# yakitonn                                           6
# okinawa soba                                       6
# sri lankan food                                    6
# sword-cut noodles                                  6
# german cuisine                                     5
# western cuisine                                    5
# croquettes and fries                               5
# onigiri                                            5
# pork bowl                                          5
# seafood rice bowl                                  5
# japanese cuisine (others)                          5
# set meals/cafeteria                                5
# chinese tea specialty store                        5
# meat buns/chinese buns                             5
# tea shop                                           5
# shanghainese cuisine                               5
# dining room                                        5
# bread sandwiches (other)                           5
# karaage                                            5
# chinese porridge                                   5
# cafe/tea room (others)                             5
# standing bar                                       5
# dandanmen                                          5
# chinese hot pot                                    5
# croquette                                          5
# cantonese                                          5
# seafood bowls                                      5
# taiyaki                                            5
# international cuisine                              5
# coffee shops                                       5
# charcoal grilled                                   5
# pub                                                5
# european style curry                               5
# bird dishes                                        4
# sweets shops                                       4
# noodles (other)                                    4
# lunch boxes                                        4
# tofu dishes                                        4
# yuba dishes                                        4
# parfaits                                           4
# dessert                                            4
# vietnamese                                         4
# fruit parlors                                      4
# southeast asian cuisine (other)                    4
# chinese pot and hot pot                            4
# deep-fried food                                    4
# obanyaki                                           4
# tofu dishes/yuba dishes                            4
# seafood don                                        4
# russian cuisine                                    4
# others                                             4
# oceanian cuisine                                   4
# motsu cuisine                                      4
# bar/liquor (others)                                4
# natural foods                                      4
# bbq                                                4
# motsu nabe                                         4
# breads/sandwiches (other)                          4
# croquette fried                                    4
# medicinal food                                     4
# pork shabu                                         4
# and other meat dishes                              4
# meat bar                                           4
# soft-serve ice cream                               3
# tempura rice bowl/tenju                            3
# grilled skewers                                    3
# whale cuisine                                      3
# spanish food                                       3
# mugitoro                                           3
# brazilian cuisine                                  3
# thai                                               3
# south asian cuisine (others)                       3
# offal cuisine                                      3
# standing bar/izakaya/bar                           3
# ox tongue                                          3
# restaurant (others)                                3
# chinese congee                                     3
# brazilian food                                     3
# thai suki                                          3
# dandanmen without soup                             3
# indonesian cuisine                                 3
# bar-bar                                            3
# tempura rice bowl                                  3
# western and european cuisine (others)              3
# bento boxes                                        3
# stand-up sushi                                     3
# dining bars                                        3
# chinese pot                                        3
# barbecue                                           3
# chinese sweets                                     3
# western food/european food (others)                3
# sports bar                                         3
# takoyaki                                           3
# fried rice                                         3
# offal hot pot                                      3
# western food/european food (other)                 3
# african cuisine                                    3
# rice ball                                          3
# suppon                                             3
# rice bowl dishes (others)                          3
# monkfish                                           3
# bread and sandwich (other)                         3
# sichuan                                            3
# beer hall                                          2
# beef cutlet                                        2
# set meals/dining rooms                             2
# turkish                                            2
# acai bowl                                          2
# set meals and cafeterias                           2
# beer restaurant                                    2
# indonesian food                                    2
# stand-up izakaya/bar                               2
# macaroons                                          2
# grilled offal                                      2
# pakistani cuisine                                  2
# houseboat/cruising                                 2
# wine bars and lounges                              2
# meat bun/chinese bun                               2
# izakaya/dining bars (other)                        2
# etc.                                               2
# hawaiian food                                      2
# asian and ethnic cuisines (others)                 2
# set meal/canteen                                   2
# pork                                               2
# donut                                              2
# udon suki                                          2
# izakaya/dining bars (others)                       2
# conveyor-belt sushi                                2
# garlic cuisine                                     2
# set meal/restaurant                                2
# cafes/tearooms (other)                             2
# chanko hotpot                                      2
# gyudon                                             2
# mexican cuisine                                    2
# nepalese food                                      2
# beef cutlets                                       2
# eel and chicken dishes                             2
# asian and ethnic food (others)                     2
# standing bar/izakaya                               2
# bar/wine bar                                       2
# california food                                    2
# sweets restaurant                                  2
# bread and sandwiches (others)                      2
# cafe / tea room (others)                           2
# breads                                             2
# bread/sandwich (others)                            2
# bread and wine bar                                 2
# liquor (other)                                     2
# california cuisine                                 2
# tea                                                2
# horse sashimi                                      2
# other                                              2
# brew pub                                           2
# soup                                               2
# mediterranean food                                 2
# beijing food                                       2
# poultry dishes                                     2
# seafood and seafood dishes                         2
# bar/liquor (other)                                 2
# bars and liquor (others)                           2
# wine bars                                          2
# cafes/coffee shops (other)                         2
# asian/ethnic (others)                              1
# deep-fried dishes                                  1
# garlic dishes                                      1
# okonomiyaki/takoyaki (other)                       1
# steakhouse                                         1
# beer hall / beer restaurant                        1
# xiao long bao                                      1
# charcoal grills                                    1
# chicken                                            1
# beer gardens                                       1
# western (other)                                    1
# soba/udon/noodles (others)                         1
# snacks                                             1
# okinawa cuisine                                    1
# latin american food (others)                       1
# horse meat cuisine                                 1
# german food                                        1
# shabu shabu                                        1
# western food/european cuisine (other)              1
# russian                                            1
# african food                                       1
# pot rice                                           1
# bar var                                            1
# butadon                                            1
# tandan noodles                                     1
# cafes and coffee shops (others)                    1
# fried croquettes                                   1
# barley                                             1
# restaurants (others)                               1
# mexican                                            1
# seafood/seafood cuisine                            1
# set meals/diner                                    1
# brazilian                                          1
# steaks                                             1
# local dishes (others)                              1
# taiyaki/large size grill                           1
# nabe (other)                                       1
# oyako-don                                          1
# western/european-style dishes (other)              1
# kiritanpo                                          1
# robata-yaki                                        1
# southeast asian food (other)                       1
# standing bars/bars                                 1
# western food (others)                              1
# sports bars                                        1
# kushiage and other meat dishes                     1
# taiwanese                                          1
# vegetarian                                         1
# pork-shabu                                         1
# western food/european style food (other)           1
# southeast asian cuisines (others)                  1
# sword-shaved noodles                               1
# sandwich and wine bar                              1
# tandanmen                                          1
# katsudon and katsuju                               1
# alcohol (others)                                   1
# international food                                 1
# izakayas                                           1
# bars/alcohol (others)                              1
# italian curry rice                                 1
# tea・snacks                                         1
# hostel                                             1
# medicinal meals                                    1
# bread and coffee shop                              1
# french cuisine                                     1
# western                                            1
# horsemeat sashimi                                  1
# central and south american cuisine (others)        1
# western food/european-style cuisine (others)       1
# cafe/cafe (others)                                 1
# cafe/coffee (other)                                1
# chanko hot pot                                     1
# and tea specialty store                            1
# akashiyaki                                         1
# mugi toro                                          1
# senbei                                             1
# korean                                             1
# café                                               1
# italian food                                       1
# delicatessen and sandwiches                        1
# soft cream                                         1
# breads and sandwiches (others)                     1
# beer restaurants                                   1
# indian                                             1
# asian/ethnic dishes (other)                        1
# taverns                                            1
# i like udon                                        1
# and udon.                                          1
# coffee shop (others)                               1
# cafe (others)                                      1
# pork cutlets                                       1
# dining bar (others)                                1
# store specializing in chinese tea                  1
# international                                      1
# tea shops                                          1
# modern spanish cuisine                             1
# rice bowl (others)                                 1
# german                                             1
# seafood and vegetable dishes                       1
# bento box                                          1
# beer halls                                         1
# vegetable                                          1
# peking food                                        1
# taiyaki/obanyaki/takoyaki                          1
# charcoal                                           1
# unagi                                              1
# fried pork                                         1
# sweets parlors                                     1
# omelette rice                                      1
# singaporean                                        1
# delicatessens                                      1
# family restaurant                                  1
# western dishes                                     1
# monkfish dishes                                    1
# taiyaki/large-sized grill                          1
# chinese hot pot/hot pot                            1
# auberge                                            1
# japanese dishes (others)                           1
# donburi (other)                                    1
# large-sized grills                                 1
# chocolate cake                                     1
# grilled robata                                     1
# bread and coffee specialty store                   1
# cafe / tea room (other)                            1
# bread/sandwiches (others)                          1
# latin american cuisine (others)                    1
# charcoal grilled chicken                           1
# peking cuisine                                     1
# international western cuisine (other)              1
# japanese tea shop                                  1
# juice bars                                         1
# crepes                                             1
# bistros                                            1
# offal grill                                        1
# singapore food                                     1
# yakiniku and other meat dishes                     1
# cafes and cafes (others)                           1
# bar bars                                           1
# shanghainese                                       1
# izakaya (japanese-style bar)                       1
# singaporean food                                   1
# Name: genre, dtype: int64

# %%
restaurants['nearest_station'].value_counts()
# Out:
# ebisu station                                         254
# ikebukuro station                                     199
# shibuya station                                       193
# roppongi station                                      185
# shimbashi station                                     180
# ginza station                                         167
# tokyo station                                         158
# iidabashi station                                     145
# omotesando station                                    137
# hiroo station                                         132
# shinjuku sanchome station                             125
# asakusa (tsukuba exp) station                         122
# jimbocho station                                      121
# kichijoji station                                     115
# akasaka station                                       111
# nakameguro station                                    109
# ningyocho station                                     105
# azabujuban station                                     94
# shinsen station                                        93
# mitsukoshimae station                                  86
# shinjuku station                                       86
# kanda station                                          85
# nogizaka station                                       83
# daikanyama station                                     80
# ginza-itchome station                                  79
# asakusa (tobu/toei/metro) station                      78
# meguro station                                         77
# nakano station                                         75
# otemachi station                                       74
# kinshicho station                                      73
# jiyugaoka station                                      72
# yotsuya sanchome station                               69
# tsukiji station                                        69
# hibiya station                                         67
# kamata station                                         66
# higashi ginza station                                  62
# sangenjaya station                                     62
# akasakamitsuke station                                 61
# gaienmae station                                       61
# ushigome kagurazaka station                            60
# kitasenju station                                      59
# seibu shinjuku station                                 59
# shimokitazawa station                                  57
# takadanobaba station                                   57
# ogikubo station                                        55
# gotanda station                                        54
# shinjuku west exit station                             52
# monzennakacho station                                  51
# azabu juban station                                    50
# machida station                                        50
# kagurazaka station                                     50
# koenji station                                         48
# uchisaiwaicho station                                  48
# gakugeidaigaku station                                 47
# yurakucho station                                      45
# oimachi station                                        44
# asakusabashi station                                   43
# suitengumae station                                    43
# nihonbashi station                                     43
# nishi-ogikubo station                                  42
# keisei ueno station                                    42
# kayabacho station                                      42
# suehirocho station                                     41
# daimon station                                         41
# mita station                                           40
# akihabara station                                      40
# shinagawa station                                      40
# ikejiri ohashi station                                 39
# shintomicho station                                    38
# mitaka station                                         38
# ogawamachi station                                     38
# futakotamagawa station                                 38
# yushima station                                        37
# kyobashi station                                       37
# suidobashi station                                     36
# toranomon hills station                                36
# kameido station                                        36
# tameike sanno station                                  35
# hongo sanchome station                                 35
# awajicho station                                       35
# nezu station                                           34
# tsukiji market station                                 34
# shirokane takanawa station                             34
# nijubashi-mae station                                  33
# toranomon station                                      33
# shirokanedai station                                   33
# okachimachi station                                    32
# tsukishima station                                     32
# akabane station                                        32
# tachikawa station                                      31
# shinjuku gyoemmae station                              31
# omori station                                          30
# hatchobori station                                     30
# yotsuya station                                        29
# kokubunji station                                      29
# sendagi station                                        29
# higashiginza station                                   29
# meiji jingumae station                                 28
# yoyogi-uehara station                                  28
# oshiage station                                        27
# sugamo station                                         27
# musashikoyama station                                  27
# asagaya station                                        27
# ichigaya station                                       26
# kuramae station                                        26
# nerima station                                         26
# takaracho station                                      26
# kudanshita station                                     26
# kameari station                                        26
# akebonobashi station                                   26
# komagome station                                       26
# edogawabashi station                                   26
# yoyogi koen station                                    25
# kojimachi station                                      25
# hachioji station                                       25
# ueno hirokoji station                                  25
# okubo station                                          25
# nagatacho station                                      24
# ryogoku station                                        24
# shiodome station                                       24
# ochanomizu station                                     24
# nishi-shinjuku station                                 23
# higashi-shinjuku station                               23
# ueno okachimachi station                               23
# mejiro station                                         23
# soshigaya okura station                                22
# yutenji station                                        22
# minami-shinjuku station                                22
# kamiyacho station                                      21
# akabanebashi station                                   21
# onarimon station                                       21
# tochomae station                                       20
# hatsudai station                                       20
# yoyogi station                                         20
# nishiogikubo station                                   20
# nipponbashi station                                    20
# kiyosumi-shirakawa station                             20
# shinjuku nishiguchi station                            20
# toritsu university station                             20
# iwamotocho station                                     20
# shin-nihonbashi station                                19
# kiba station                                           19
# jujo station                                           19
# otsuka station                                         19
# shinkoiwa station                                      19
# kyodo station                                          19
# nakaokachimachi station                                19
# myogadani station                                      19
# nippori station                                        19
# musashisakai station                                   18
# nishinippori station                                   18
# tawaramachi station                                    18
# nijubashimae station                                   18
# uguisudani station                                     17
# kitasando station                                      17
# shin-okubo station                                     17
# nishitaishido station                                  17
# shinjuku gyoenmae station                              17
# roppongi itchome station                               17
# roppongi-itchome station                               17
# koiwa station                                          17
# sasazuka station                                       16
# tamachi station                                        16
# honjoazumabashi station                                16
# oyama station                                          16
# ueno station                                           15
# haneda airport terminal 2 (tokyo monorail) station     15
# otsuka ekimae station                                  15
# yoyogiuehara station                                   15
# higashinakano station                                  15
# iriya station                                          15
# kodemmacho station                                     15
# inaricho station                                       15
# morishita station                                      15
# kunitachi station                                      14
# hanzomon station                                       14
# ekoda station                                          14
# kasuga station                                         14
# waseda (toden) station                                 14
# tachikawa north station                                14
# shin-okachimachi station                               14
# keikyu kamata station                                  14
# shin-ochanomizu station                                13
# shin-nakano station                                    13
# meijijingumae station                                  13
# tachikawaminami station                                13
# aoyama-itchome station                                 13
# chofu station                                          13
# kachidoki station                                      13
# okusawa station                                        13
# higashijujo station                                    13
# tokyo skytree station                                  13
# hatagaya station                                       13
# kiyosumi shirakawa station                             12
# nogata station                                         12
# nishiwaseda station                                    12
# yoyogi hachiman station                                12
# sengawa station                                        12
# sakurashinmachi station                                12
# sakuradai station                                      12
# toritsudaigaku station                                 11
# takanawadai station                                    11
# chitose karasuyama station                             11
# keiseitateishi station                                 11
# ookayama station                                       11
# keio hachioji station                                  11
# omokagebashi station                                   11
# osakihirokoji station                                  11
# kitashinagawa station                                  11
# oji ekimae station                                     11
# bakurocho station                                      11
# shinokubo station                                      11
# higashiikebukuro station                               10
# itabashi station                                       10
# haneda airport terminal 1 (tokyo monorail) station     10
# omori kaigan station                                   10
# toyocho station                                        10
# hamamatsucho station                                   10
# tanashi station                                        10
# nishikasai station                                     10
# sangubashi station                                     10
# toden zoshigaya station                                10
# shinnihonbashi station                                 10
# shibakoen station                                      10
# hikifune station                                       10
# komazawa university station                             9
# mikawashima station                                     9
# umegaoka station                                        9
# yoga station                                            9
# tabata station                                          9
# takebashi station                                       9
# bakuroyokoyama station                                  9
# keisei seiseki station                                  9
# minamiasagaya station                                   9
# kamiigusa station                                       9
# kamimachi station                                       9
# kasai station                                           9
# minowa station                                          9
# musashi-koganei station                                 9
# hamacho station                                         9
# waseda (metro) station                                  9
# shakujii koen station                                   9
# horikiri shobuen station                                8
# sumiyoshi station                                       8
# setagaya daita station                                  8
# toyosu station                                          8
# shoin shrine-mae station                                8
# nishi-shinjuku gochome station                          8
# kanamecho station                                       8
# kikugawa station                                        8
# koshinzuka station                                      8
# kamiitabashi station                                    8
# osaki station                                           8
# shinkoenji station                                      8
# togoshi ginza station                                   8
# fudomae station                                         8
# harajuku station                                        8
# hatanodai station                                       8
# komaba todaimae station                                 8
# national stadium station                                8
# gokokuji station                                        8
# oyamadai station                                        8
# fuchu station                                           8
# seijo gakuen-mae station                                7
# kuhonbutsu station                                      7
# kawabe station                                          7
# musashi koyama station                                  7
# ichibae station                                         7
# fudozen station                                         7
# higashi-koganei station                                 7
# osaki hirokoji station                                  7
# tachikawa minami station                                7
# nishikoyama station                                     7
# shibamata station                                       7
# bubaigawara station                                     7
# korakuen station                                        7
# nakanosakaue station                                    7
# hirai station                                           7
# nishi-hachioji station                                  7
# higashi nakano station                                  6
# todoroki station                                        6
# ikenoue station                                         6
# higashi-mukojima station                                6
# sendagaya station                                       6
# shinbaba station                                        6
# tokiwadai station                                       6
# komazawadaigaku station                                 6
# mukaihara station                                       6
# hasunuma station                                        6
# togoshi station                                         6
# kodenmacho station                                      6
# shiinamachi station                                     6
# itabashi ward yakusho-mae station                       6
# machiya ekimae station                                  6
# shin-otsuka station                                     6
# hachimanyama station                                    6
# takeshiba station                                       6
# eifukucho station                                       5
# ochiai station                                          5
# kanamachi station                                       5
# ikegami station                                         5
# omorimachi station                                      5
# minamisenju station                                     5
# shindaita station                                       5
# chitose-funabashi station                               5
# higashi-ikebukuro station                               5
# sengoku station                                         5
# nishimagome station                                     5
# itabashihonmachi station                                5
# nishidai station                                        5
# tokyo big sight station                                 5
# hanakoganei station                                     5
# kamikitazawa station                                    5
# denenchofu station                                      5
# chitose funabashi station                               5
# kokuryo station                                         5
# ayase station                                           5
# higashi-nagasaki station                                5
# todaimae station                                        5
# kiyose station                                          5
# hoya station                                            5
# takahatafudo station                                    5
# numabukuro station                                      5
# ashikakoen station                                      5
# market front station                                    5
# meidaimae station                                       4
# gotokuji station                                        4
# kotakemukaihara station                                 4
# musashi koganei station                                 4
# nishi-kokubunji station                                 4
# shinozaki station                                       4
# akatsuka subway station                                 4
# musashiseki station                                     4
# higashinakagami station                                 4
# haneda airport terminal 3 (tokyo monorail) station      4
# fujimidai station                                       4
# subway narimasu station                                 4
# higashi-kitazawa station                                4
# shinitabashi station                                    4
# nakaitabashi station                                    4
# hakusan station                                         4
# higashikoenji station                                   4
# shimoshinmei station                                    4
# keisei koiwa station                                    4
# minowabashi station                                     4
# nishi oshima station                                    4
# ebara nakanobu station                                  4
# iogi station                                            4
# akabaneiwabuchi station                                 4
# sengakuji station                                       4
# kojiya station                                          4
# takaosanguchi station                                   4
# oizumi gakuen station                                   4
# tennozu isle station                                    4
# shimotakaido station                                    4
# hitotsubashi gakuen station                             4
# nishiarai station                                       4
# kamishakujii station                                    4
# higashi-nihonbashi station                              4
# shin-akitsu station                                     4
# shimotsai station                                       4
# higashifushimi station                                  4
# naruse station                                          4
# fussa station                                           3
# toyota station                                          3
# nishi-kunitachi station                                 3
# setagaya station                                        3
# yoyogihachiman station                                  3
# tobu nerima station                                     3
# toshimaen station                                       3
# heiwajima station                                       3
# keisei hikifune station                                 3
# chitosekarasuyama station                               3
# hachioji minamino station                               3
# nishichofu station                                      3
# nakagami station                                        3
# chidoricho station                                      3
# oshima station                                          3
# ebaramachi station                                      3
# umejima station                                         3
# nakanobu station                                        3
# yagawa station                                          3
# inokashira koen station                                 3
# oizumigakuen station                                    3
# tachiaigawa station                                     3
# otorii station                                          3
# honancho station                                        3
# hamadayama station                                      3
# aoto station                                            3
# zoshiki station                                         3
# komiya station                                          3
# kitaayase station                                       3
# nishiojima station                                      3
# nakamurabashi station                                   3
# honkomagome station                                     3
# fuchuhonmachi station                                   3
# nakanofujimicho station                                 3
# ushihama station                                        3
# higashinihonbashi station                               3
# shinsakuradai station                                   3
# senju ohashi station                                    3
# shibasaki station                                       3
# ichinoe station                                         3
# kitami station                                          3
# aomono yokocho station                                  3
# seiseki sakuragaoka station                             3
# arakawa nana-chome station                              3
# hibarigaoka station                                     3
# midorigaoka station                                     3
# aomonoyokocho station                                   3
# kishibojinmae station                                   3
# yukigaya otsuka station                                 3
# anamori inari station                                   3
# kitafuchu station                                       3
# keisei kanamachi station                                3
# daitabashi station                                      3
# seijogakuenmae station                                  3
# furubuchi station                                       2
# shiraitodai station                                     2
# machiya nichome station                                 2
# zoshigaya (tokyo metro) station                         2
# daiba station                                           2
# national diet building station                          2
# sawai station                                           2
# hikarigaoka station                                     2
# yaho station                                            2
# keisei takasago station                                 2
# heiwadai station                                        2
# shin-sakuradai station                                  2
# nishisugamo station                                     2
# tsutsujigaoka station                                   2
# funabori station                                        2
# senzoku station                                         2
# ushigome yanagimachi station                            2
# minami asagaya station                                  2
# nakai station                                           2
# takanawa gateway station                                2
# saginomiya station                                      2
# minamimachida granberry park station                    2
# komae station                                           2
# shin-ekoda station                                      2
# keio horinouchi station                                 2
# higashi koenji station                                  2
# higashikurume station                                   2
# tama station                                            2
# oji kamiya station                                      2
# haneda airport terminal 3 (keikyu) station              2
# shimoakatsuka station                                   2
# wakamatsukawada station                                 2
# gotanno station                                         2
# shinonome station                                       2
# yamada station                                          2
# kitahachioji station                                    2
# shimurasakagami station                                 2
# wakabayashi station                                     2
# musashi-masuto station                                  2
# minami machida grandberry park station                  2
# seibu yanagisawa station                                2
# akigawa station                                         2
# takenotsuka station                                     2
# sakurajosui station                                     2
# kugahara station                                        2
# seibu tachikawa station                                 2
# shimoigusa station                                      2
# nishikunitachi station                                  2
# haijima station                                         2
# nagahara station                                        2
# ohanajaya station                                       2
# shin-itabashi station                                   2
# nakano-shinbashi station                                2
# arakawa yuenchimae station                              2
# higashimurayama station                                 2
# odakyu nagayama station                                 2
# kaminoge station                                        2
# ushita station                                          2
# rokumachi station                                       2
# kugayama station                                        2
# magome station                                          2
# sugamo shinden station                                  2
# kumegawa station                                        2
# sugamo nitta station                                    2
# nishieifuku station                                     2
# araiyakushimae station                                  2
# oumekaido station                                       2
# higashi nagasaki station                                2
# kanegafuchi station                                     2
# kumagawa station                                        1
# higashiikebukuro 4-chome station                        1
# keio tama center station                                1
# arakawa nanchome station                                1
# wakamatsu kawata station                                1
# furusato station                                        1
# higashiazuma station                                    1
# higashi-ome station                                     1
# musashi sunagawa station                                1
# keio katakura station                                   1
# yahiro station                                          1
# akitsu station                                          1
# sunagawa seven station                                  1
# okutama station                                         1
# akishima station                                        1
# ochiai minami nagasaki station                          1
# shiromaru station                                       1
# miyanosaka station                                      1
# hinode station                                          1
# shinkiba station                                        1
# ome station                                             1
# higashi-oshima station                                  1
# saifu station                                           1
# musashi itsukaichi station                              1
# shibaurafuto station                                    1
# takanodai station                                       1
# shimurasakaue station                                   1
# higashifussa station                                    1
# musashishinden station                                  1
# hazama station                                          1
# karakida station                                        1
# mogusaen station                                        1
# miyanomae station                                       1
# higashiakiru station                                    1
# narimasu station                                        1
# shimura sanchome station                                1
# nishi-oi station                                        1
# mitake station                                          1
# hikawadai station                                       1
# umeyashiki station                                      1
# tama center station                                     1
# arakawa 2-chome station                                 1
# keio nagayama station                                   1
# kumanomae station                                       1
# inokashira park station                                 1
# toritsu kasei station                                   1
# kita-ayase station                                      1
# kodaira station                                         1
# motohasunuma station                                    1
# shin-shibamata station                                  1
# hamura station                                          1
# daishimae station                                       1
# kameidosuijin station                                   1
# mejirodai station                                       1
# shimo station                                           1
# sakaemachi station                                      1
# machiya station                                         1
# shin-koenji station                                     1
# tamareien station                                       1
# izumi tamagawa station                                  1
# oku station                                             1
# tanizaike station                                       1
# musashi nitta station                                   1
# yaguchito station                                       1
# hasune station                                          1
# ushigome yanagicho station                              1
# shimomaruko station                                     1
# metropolitan kasei station                              1
# manganji station                                        1
# higashiogu sanchome station                             1
# minamiosawa station                                     1
# hyugawada station                                       1
# kajiwara station                                        1
# hino station                                            1
# hashimoto station                                       1
# seisekisakuragaoka station                              1
# shin otsuka station                                     1
# katakura station                                        1
# shin-kodaira station                                    1
# hinatawada station                                      1
# shin-yurigaoka station                                  1
# yotsugi station                                         1
# kitano station                                          1
# otsuka/teikyodaigaku station                            1
# arai yakushimae station                                 1
# gakushuinshita station                                  1
# musashi yamato station                                  1
# minamitama station                                      1
# higashioku sanchome station                             1
# takao station                                           1
# inagi station                                           1
# sakurakaido station                                     1
# odaiba seaside park station                             1
# higashi-ikebukuro yonchome station                      1
# higashikitazawa station                                 1
# nerima kasugacho station                                1
# shinanomachi station                                    1
# tsurukawa station                                       1
# tamagawa gakuen-mae station                             1
# mitakadai station                                       1
# kishimojinmae station                                   1
# nishi-takashimadaira station                            1
# Name: nearest_station, dtype: int64

# %%
pd.reset_option('display.max_rows')

# %% [markdown]
# ### Testing the Recommendation Function

# %% [markdown]
# To ensure that the `recommend_by_genre` function works as expected, a test is conducted using specific user preferences. Please feel free to multiselect any genres and pair it with any one of the nearest stations from above.
#
# **Test Criteria:**
# - **Selected Genres:** `ramen` and `poultry dishes`
# - **Nearest Station:** `ebisu station`
#
# By running this test, the function should return <u>up to the top 10 restaurants</u> that serve either Ramen or Poultry Dishes and are located near the Ebisu Station. These restaurants are further sorted by their ratings to give the user the best recommendations based on their criteria.

# %%
# Test the recommendation function
recommend_by_genre(['ramen', 'poultry dishes'], nearest_station='ebisu station')
# Out:
#                                                name  rating_val  \
# 738                           ozeki chinese noodles        3.75
# 1157      hand-made chicken chinese noodles ayagawa        3.72
# 1896  miso ramen kakitagawa hibari ebisu main store        3.67
# 2142                                         tether        3.65
# 2362                 tsukumo ramen ebisu main store        3.64
# 2707                                 mentei shimada        3.62
# 3230                                       shionuki        3.60
# 3155                      kouyu ramen chorori ebisu        3.60
# 4068                                  shuichi ebisu        3.56
# 5453                                    afuri ebisu        3.52
#
#      nearest_station
# 738    ebisu station
# 1157   ebisu station
# 1896   ebisu station
# 2142   ebisu station
# 2362   ebisu station
# 2707   ebisu station
# 3230   ebisu station
# 3155   ebisu station
# 4068   ebisu station
# 5453   ebisu station

# %% [markdown]
# ![](images/screenshot3.png)
#
# ---

# %% [markdown]
# **Test Criteria:**
# - **Selected Genres:** `ramen`
# - **Nearest Station:** `zoshiki station`
#
# Here we have chosen to pick Ramen to recommend restaurants near Zoshiki Station, which is a lesser-known station, hence returning only one recommendation.

# %%
# Test the recommendation function
recommend_by_genre(['ramen'], nearest_station='zoshiki station')
# Out:
#                                                   name  rating_val  \
# 154  shinjiko shijimi chinese soba kohaku tokyo mai...        3.96
#
#      nearest_station
# 154  zoshiki station

# %% [markdown]
# ![](images/screenshot2.png)
#
# ---

# %% [markdown]
# **Test Criteria:**
# - **Selected Genres:** `spanish cuisine`
# - **Nearest Station:** `gakugeidaigaku station`
#
# Based on this test, it's evident that our model prioritizes accuracy and does not provide arbitrary recommendations. For instance, it correctly identified the absence of Spanish cuisine near Kitano Station.

# %%
# Test the recommendation function
recommend_by_genre(['spanish cuisine'], nearest_station='kitano station')
# Out:
# Empty DataFrame
# Columns: [name, rating_val, nearest_station]
# Index: []

# %% [markdown]
# ![](images/screenshot1.png)
#
# ---

# %% [markdown]
# By continually testing with different criteria, the reliability and accuracy of the recommendation system can be ensured.

# %% [markdown]
# ## Exporting Files

# %%
# Creating Folder 'StreamLit'
if not os.path.exists('StreamLit'):
    os.makedirs('StreamLit')

# %%
#Export
with h5py.File('StreamLit/cosine_sim.h5', 'w') as hf:
    hf.create_dataset("cosine_similarity", data=cosine_sim)

restaurants.to_csv('StreamLit/restaurants_model.csv', index=False)

# %%
# File path
file_path = 'StreamLit/cosine_sim.h5'

# Open the file in read mode
with h5py.File(file_path, 'r') as file:
    # Print the names of the datasets in the file
    print("Keys: %s" % file.keys())
    
    # Access the 'cosine_similarity' dataset
    cosine_sim_dataset = file['cosine_similarity']
    
    # Print the shape of the dataset
    print("Shape of the dataset:", cosine_sim_dataset.shape)
    
    # Print the data type of the dataset
    print("Data type:", cosine_sim_dataset.dtype)
    
    # Check and print if the matrix is sparse
    if isinstance(cosine_sim_dataset, h5py.Group) and 'data' in cosine_sim_dataset and 'indices' in cosine_sim_dataset:
        print("The matrix is stored in a sparse format.")
    else:
        print("The matrix is stored in a dense format.")

# Get and print the file size
file_size = os.path.getsize(file_path) / (1024 * 1024)  # Convert from bytes to megabytes
print(f"File size: {file_size:.2f} MB")
# Out:
# Keys: <KeysViewHDF5 ['cosine_similarity']>
# Shape of the dataset: (10000, 10000)
# Data type: float64
# The matrix is stored in a dense format.
# File size: 762.94 MB

# %% [markdown]
# ### File Size Considerations for GitHub

# %% [markdown]
# Upon inspection of our `cosine_similarity` dataset within the HDF5 file, we found that the file size is approximately `762.94 MB`, which exceeds GitHub's file size limit.
#
# To accommodate this, we'll be compressing the dataset using the GZIP compression algorithm within HDF5. This approach should effectively reduce the file size, making it suitable for hosting on GitHub.
#
# By using this method, we aim to ensure that the data retains its integrity while making it more accessible for collaboration and version control on GitHub.

# %%
# Compress the cosine similarity matrix and save it
with h5py.File('StreamLit/compressed_cosine_sim.h5', 'w') as file:
    file.create_dataset('cosine_similarity', data=cosine_sim, compression="gzip")

# Delete the original, uncompressed file
os.remove('StreamLit/cosine_sim.h5')

# %% [markdown]
# ## Saving files for Streamlit

# %% [markdown]
# ### Lottie Animation Integration

# %% [markdown]
# Lottie is a popular animation library that lets you run animations in real-time, making them appear more live and dynamic than traditional GIFs or video formats. These animations are often driven by JSON files.
#
# 1. **Fetching the Lottie Animation**: We start by defining a function, `load_lottie_url`, that retrieves a Lottie animation in the form of a JSON using a specified URL. If the request is successful, it returns the JSON data; otherwise, it returns `None`.
#
# 2. **Storing the Lottie Animation**: Once we have the JSON data for the Lottie animation, we might want to save it locally for various reasons such as offline access or embedding it within our application. The function `save_lottie_to_file` is designed to save the Lottie JSON data to a file within the `StreamLit` directory.
#
# 3. **Implementation**: After defining our helper functions, we specify a Lottie animation URL and fetch its JSON data. If the fetch is successful, the Lottie JSON data is saved using the previously defined function, making it available for local access or embedding within the application.

# %%
# Function to load animation from Lottie
def load_lottie_url(url: str):
    r = requests.get(url)
    if r.status_code != 200:
        return None
    return r.json()

# Function to save Lottie JSON to a specified file within the 'model' directory
def save_lottie_to_file(lottie_data, filename='lottie_data.json'):
    filepath = os.path.join('StreamLit', filename)
    
    with open(filepath, 'w') as file:
        json.dump(lottie_data, file)

# Display a Lottie animation
lottie_url = "https://lottie.host/5870e9fb-3411-4d1b-9eb9-53bf39503d08/wQBcaepzHp.json"
lottie_json = load_lottie_url(lottie_url)

# Save the Lottie JSON data
if lottie_json:
    save_lottie_to_file(lottie_json)

# %% [markdown]
# ### Geocoding Utility

# %% [markdown]
# The ability to convert an address into geographical coordinates (latitude and longitude) is crucial for many location-based applications. This script provides a geocoding utility using an external API service.
#
# **Functionality Breakdown**:
#
# 1. **API Configuration**: The geocoding service used here is provided by `geloky.com`. The function `get_coordinates_from_address` is responsible for making requests to this service. An API key is necessary for authenticating the requests.
#
# 2. **Default Coordinates**: As a backup mechanism, in case the geocoding service fails to provide coordinates for a given address or if there's an issue with the API, the script has default coordinates set to Tokyo's geographical center. This ensures that the function always returns a set of coordinates. We can also use this to evaluate if our model is accurately giving us correct coordinates, or if it is unable to process the addresses given.
#
# 3. **API Call and Data Parsing**: When the function is called with an address:
#     - It constructs the API request URL.
#     - Makes an HTTP GET request to the service.
#     - Parses the JSON response to extract the latitude and longitude.
#
# 4. **Error Handling**: If the API doesn't return successful results, or if the address doesn't match any known locations in the geocoding service's database, the function prints a relevant message and falls back to the default Tokyo coordinates.
#
# **Usage**: This script can be integrated into applications where geographical data is required. It abstracts the complexities of interacting with the geocoding API and provides a straightforward method to get coordinates from an address.

# %%
# %%writefile StreamLit/geocoding.py

import streamlit as st
import requests

def get_coordinates_from_address(address):
    API_KEY = st.secrets["API_KEY"]
    url = f"https://geloky.com/api/geo/geocode?address={address}&key={API_KEY}&format=geloky"

    TOKYO_LAT = 35.6895
    TOKYO_LONG = 139.6917

    response = requests.get(url)

    if response.status_code == 200:
        data = response.json()

        # Check if the list is empty
        if not data:
            print(f"No matching results for address: {address}")
            return TOKYO_LAT, TOKYO_LONG  # Default Tokyo coordinates

        result = data[0]  # Access the first dictionary in the list
        latitude = result["latitude"]
        longitude = result["longitude"]
        return latitude, longitude
    else:
        print(f"Request failed with status code {response.status_code}")
        return TOKYO_LAT, TOKYO_LONG  # Default Tokyo coordinates in case of an API failure
# Out:
# Overwriting StreamLit/geocoding.py

# %% [markdown]
# ## Deployment on StreamLit

# %%
# %%writefile StreamLit/recommender_app_genre.py

import streamlit as st
from streamlit_lottie import st_lottie
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
import boto3
import io
import s3fs
import h5py
import requests
import json
from geocoding import get_coordinates_from_address


# Load pre-computed cosine similarities and the restaurant dataset
with h5py.File('compressed_cosine_sim.h5', 'r') as file:
    cosine_sim = file['cosine_similarity'][:]

restaurants = pd.read_csv('restaurants_model.csv')


# Drop unnecessary columns to leave only genre features
genres_df = restaurants.drop(columns=['name', 'genre', 'rating_val', 'nearest_station', 'address'])


# Load the Lottie JSON data from the local file
with open('lottie_data.json', 'r') as file:
    lottie_data_from_file = json.load(file)

    
# Display the Lottie animation using the loaded data
st_lottie(lottie_data_from_file, speed=1, width=800, height=500, key="initial")


# Function to recommend restaurants based on selected genres and optionally, a nearest station
def recommend_by_genre(input_genres, nearest_station=None, cosine_sim=cosine_sim, min_similarity=0.3):
    # Check if all selected genres exist in the dataset
    for genre in input_genres:
        if genre not in genres_df.columns:
            return f"Genre {genre} not found in the dataset"

    # Create a combined genre vector for all selected genres
    genre_vector = np.zeros(genres_df.shape[1])
    for genre in input_genres:
        genre_index = list(genres_df.columns).index(genre)
        genre_vector[genre_index] = 1

    # Normalize the genre vector and reshape
    genre_vector /= len(input_genres)
    genre_vector = genre_vector.reshape(1, -1)

    # Compute the cosine similarity scores for the genre vector against all restaurants
    sim_scores = cosine_similarity(genre_vector, genres_df.values)
    sim_scores = [x for x in enumerate(sim_scores[0]) if x[1] >= min_similarity]
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # If a station is selected, filter by that station
    if nearest_station:
        station_filtered_indices = [i[0] for i in sim_scores if restaurants.iloc[i[0]]['nearest_station'] == nearest_station]
        top_10_indices = station_filtered_indices[:10]
    else:
        top_10_indices = [i[0] for i in sim_scores[:10]]

    # Get the top 10 restaurants and sort them by rating
    top_10_restaurants = restaurants.iloc[top_10_indices]
    sorted_restaurants = top_10_restaurants.sort_values(by='rating_val', ascending=False)
    return sorted_restaurants[['name', 'rating_val', 'nearest_station']]
    

# Streamlit UI: Select genres and a station
selected_genres = st.multiselect(
    "Select genres to get restaurant recommendations:", genres_df.columns
)
selected_station = st.selectbox("Choose a nearby station:", restaurants['nearest_station'].unique())


# Button to get recommendations
if st.button("Recommend"):
    recommended_data = recommend_by_genre(selected_genres, selected_station)
    
    # Check if the result is a string (indicating an error message) or an empty dataframe
    if isinstance(recommended_data, str):
        st.write(recommended_data)
    elif recommended_data.empty:
        st.write("No restaurants found based on the selected criteria. Please modify your selection.")
    else:
        recommended_data = recommended_data.rename(columns={"name": "Name", "rating_val": "Rating", "nearest_station": "Nearest Station"})
        
        # Ensure that 'address' column is present in recommended_data
        recommended_data = pd.merge(recommended_data, restaurants[['name', 'nearest_station', 'address']], 
                                left_on=['Name', 'Nearest Station'], 
                                right_on=['name', 'nearest_station'], 
                                how='left').drop_duplicates()

        # Geocode the addresses of the recommended restaurants only
        recommended_data['latitude'], recommended_data['longitude'] = zip(*recommended_data['address'].map(get_coordinates_from_address))

        st.table(recommended_data[['Name', 'Rating', 'Nearest Station']])

        # Display map
        st.map(recommended_data[['latitude', 'longitude']])
# Out:
# Overwriting StreamLit/recommender_app_genre.py

# %% [markdown]
# [Click here to access Tokyo Restaurants Recommender Streamlit](https://tokyo-restaurants.streamlit.app/)
