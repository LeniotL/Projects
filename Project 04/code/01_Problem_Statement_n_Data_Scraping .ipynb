# %% [markdown]
# # ![](https://ga-dash.s3.amazonaws.com/production/assets/logo-9f88ae6c9c3871690e33280fcf557f33.png) Project 4: Predict Dengue Cases

# %% [markdown]
# [![](../images/denguecampaign-wpfb-v2.jpg)](https://www.nea.gov.sg/dengue-zika/dengue)

# %% [markdown]
# # <u>Background</u>

# %% [markdown]
# Dengue fever is a mosquito-borne viral illness that poses a significant public health threat in Singapore. Dengue fever is endemic in Singapore, with frequent outbreaks causing considerable morbidity and occasionally even mortality. With the incidence of <u>[**dengue increasing globally**](https://www.paho.org/en/news/3-8-2023-dengue-cases-increase-globally-vector-control-community-engagement-key-prevent-spread#:~:text=During%20the%20EPI%2DWIN%20Webinar,million%20infections%20occurring%20each%20year.)</u>, it is crucial to implement effective prevention and control strategies.
#
# In Singapore, the National Environmental Agency (NEA) has initiated several programs to combat the spread of dengue, including the launch of <u>[**Project Wolbachia**](https://www.nea.gov.sg/corporate-functions/resources/research/wolbachia-aedes-mosquito-suppression-strategy)</u>. This innovative project involves the release of male mosquitoes infected with the Wolbachia bacteria, which causes the eggs laid by female mosquitoes to be non-viable, reducing the mosquito population and the transmission of dengue.
#
# Despite these efforts, predicting the number of dengue cases and understanding the trends in dengue outbreaks remain challenges. Weather patterns, public awareness, and the success of Project Wolbachia all play a role in influencing the incidence of dengue.
#
# As part of the <u>[**Vector Biology and Control Division (VBCD)**](https://www.nea.gov.sg/corporate-functions/who-we-are/groups-and-divisions/public-health-groups-and-divisions)</u>, we carry out research and surveillance of mosquitoes and other vectors and risk assessment of present and future vector-borne diseases that pose a public health threat to Singapore. The division continually explores and evaluates new and safe control tools, and develops novel strategies for risk intervention and management tailored to Singapore's unique urban and dense landscape.

# %% [markdown]
# # <u>Problem Statement</u>

# %% [markdown]
# Dengue fever is a serious public health concern in Singapore, leading to considerable <u>[**morbidity**](https://www.straitstimes.com/singapore/health/singapore-records-19-dengue-deaths-in-2022-nearly-four-times-2021-s-toll#:~:text=SINGAPORE%20%2D%20There%20were%2019%20deaths,people%20died%20of%20the%20disease.)</u> and <u>[**economic burden**](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10021432/#:~:text=We%20estimated%20that%20the%20average,21%2C262%20DALYs%20from%202010%E2%80%932020.)</u>. The National Environmental Agency (NEA) is tasked with managing and reducing the impact of dengue in the country. Predicting dengue outbreaks is a complex task that requires taking into account a variety of factors, including environmental, social, and behavioral variables.
#
# Project Wolbachia in Singapore aims to reduce dengue transmission by releasing mosquitoes infected with Wolbachia bacteria. However, the project has faced challenges including ecological concerns, <u>[**skepticism from the community**](https://www.todayonline.com/voices/project-wolbachia-residents-are-killing-helpful-mosquitoes-which-can-be-nuisance)</u>, <u>[**high costs**](https://journals.plos.org/globalpublichealth/article?id=10.1371/journal.pgph.0000024#:~:text=Under%20an%20assumed%20steady%2Dstate,to%202020%20under%2040%25%20intervention)</u>, <u>[**weather disruptions**](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC9098883/)</u>, and integration with other control measures. Monitoring and evaluating the project's impact are essential for its success and to inform future dengue control strategies.
#
# As part of the VBCD, we seek to develop a predictive model capable of forecasting the number of dengue cases and understanding the trends in dengue outbreaks for a subsequent period. The model would incorporate a wide range of relevant factors that influence the spread of dengue, over a period of 2012 to 2023.
#
# Specifically, the model should include:
#
# 1. **Weather Data**: It is well-known that climatic conditions play a pivotal role in affecting mosquito behavior and the spread of dengue fever. Hence, the model will incorporate data on weather variables such as temperature, humidity, and rainfall to assess their potential influence on dengue cases.
#
# 2. **Google Search Trends**: A notable indicator of public awareness and concern regarding dengue is the volume of related search queries on Google. Therefore, the model will include Google search trends data on dengue-related terms spanning to reflect the behavioral dynamics that might contribute to the spread of the disease.
#
# 3. **Project Wolbachia Data**: Project Wolbachia, initiated to curb the transmission of dengue, involves the release of mosquitoes infected with Wolbachia bacteria, impairing their ability to transmit the virus. The model will take into account data on the timing and locations of Project Wolbachia releases to understand their potential impact on the incidence of dengue cases.
#
# Accurate predictions from the model can have significant implications for public health in Singapore. With reliable forecasts, the VBCD can:
#
# 1. **Allocate Resources Efficiently**: By anticipating dengue outbreaks, the VBCD can allocate resources, such as mosquito control teams and public health campaigns, more efficiently to areas at higher risk.
#
# 2. **Target Prevention Measures Effectively**: With insights into the factors driving dengue outbreaks, the VBCD can tailor prevention measures, such as fogging, removal of breeding sites, and public education, to specific high-risk areas and times.
#
# 3. **Raise Public Awareness**: During periods of high predicted risk, the VBCD can increase public awareness campaigns to inform residents about the importance of mosquito control and dengue prevention measures.
#
# 4. **Assess the Impact of Project Wolbachia**: By incorporating data on Project Wolbachia, the model can provide insights into the effectiveness of the program and inform decisions on future releases of Wolbachia-infected mosquitoes.
#
# Ultimately, the development of a robust predictive model for dengue cases in Singapore will contribute to more effective dengue management and prevention strategies, thereby reducing the impact of dengue on public health and the economy.

# %% [markdown]
# # <u>Methodology</u>

# %% [markdown]
# **1. Data Collection and Integration**
#    - **Weather Data:** Collect and integrate weather data such as temperature, humidity, and rainfall, which influence mosquito behavior and dengue transmission.
#    - **Dengue Cases Data:** Obtain historical weekly dengue cases data to understand the patterns and trends of dengue outbreaks in Singapore.
#    - **Google Search Trends Data:** Acquire Google trends data on dengue-related search terms to gauge public awareness and concern about dengue.
#    - **Project Wolbachia Data:** Collect data on the release of Wolbachia-infected mosquitoes, including the timing, location, and scale of each release.
#
# **2. Data Preprocessing and Cleaning**
#    - **Data Wrangling:** Clean, transform, and integrate data from various sources into a unified dataset suitable for analysis.
#    - **Missing Data and Outliers:** Handle missing values and outliers to ensure data quality and reliability.
#    - **Temporal Alignment:** Aggregate and align data on a weekly or monthly basis to match the frequency of dengue cases data.
#
# **3. Exploratory Data Analysis (EDA)**
#    - **Descriptive Statistics:** Generate summary statistics and visualizations to understand the distribution, patterns, and relationships among variables.
#    - **Trends and Seasonality:** Analyze temporal patterns, including trends and seasonality, in the dengue cases data.
#    - **Correlation Analysis:** Identify potential relationships between weather variables, Google search trends, Project Wolbachia data, and dengue cases.
#
# **4. Feature Engineering**
#    - **Lag Variables:** Create lag variables for weather data and Google search trends to capture their delayed effects on dengue cases.
#    - **Interaction Terms:** Generate interaction terms among weather variables to account for their combined effects on dengue transmission.
#    - **Geospatial Features:** Encode the location of dengue clusters and Project Wolbachia releases as numeric features.
#
# **5. Modeling and Prediction**
#    - **SARIMAX Model:** Build a SARIMAX model to forecast the number of dengue cases, incorporating external regressors such as weather data and Google search trends.
#    - **Hyperparameter Tuning:** Optimize the model's hyperparameters to enhance its predictive performance.
#
# **6. Model Evaluation**
#    - **Model Validation:** Split the data into training and validation sets to assess the model's performance on unseen data.
#    - **Evaluation Metrics:** Use appropriate metrics, such as MAE, MSE, or RMSE, to evaluate the model's accuracy in predicting dengue cases.
#
# **7. Cost-Benefit Analysis**
#    - **Cost Estimation:** Estimate the annual costs of the dengue prevention program, including Project Wolbachia, public awareness campaigns, and other interventions.
#    - **Benefit Quantification:** Quantify the benefits of the program in terms of reduced dengue cases, healthcare costs, and productivity losses.
#    - **Trade-Off Analysis:** Assess the trade-offs between the costs and benefits of the program to optimize resource allocation and maximize benefits.
#
# **8. Recommendations and Insights**
#    - **Policy Recommendations:** Provide recommendations to the NEA for targeted dengue prevention measures based on the model's predictions and cost-benefit analysis.
#    - **Model Interpretation:** Offer insights into the factors contributing to dengue outbreaks and the effectiveness of Project Wolbachia.
#
# This methodology outlines a comprehensive approach to predict dengue cases in Singapore, assess the cost-benefit of the dengue prevention program, and provide actionable recommendations to the NEA.

# %% [markdown]
# # <u>Objective</u>

# %% [markdown]
# 1. Collect and preprocess data on weather patterns, dengue clusters, Google search trends for dengue, and Project Wolbachia releases.
# 2. Conduct exploratory data analysis to understand the relationships between the collected variables and the number of dengue cases.
# 3. Engineer relevant features that can improve the predictive power of the model.
# 4. Experiment with different models to forecast the number of dengue cases for the subsequent period, incorporating the identified features and external regressors.
# 5. Evaluate the performance of the model using the Mean Absolute Percentage Error (MAPE) metric to assess the accuracy of its predictions as a percentage of the actual number of dengue cases.
# 6. Analyze the model's results and provide insights into the factors contributing to the predicted number of dengue cases and trends.
# 7. Conduct a cost-benefit analysis of the dengue prevention program, including:
#    - Estimating the annual cost of the dengue prevention program, including the costs associated with Project Wolbachia releases, public awareness campaigns, and other prevention measures.
#    - Quantifying the benefits of the program in terms of the reduction in the number of dengue cases, the reduction in the economic burden of dengue (e.g. productivity losses), and the improvement in public health.
#    - Assessing the trade-offs between the costs and benefits of the program, considering the optimal allocation of resources to maximize the benefits and minimize the costs.
#    - Providing recommendations for optimizing the dengue prevention program to achieve maximum benefits at the lowest possible cost.
# 8. Provide recommendations to the NEA based on the model's predictions and the cost-benefit analysis, including potential modifications to the Project Wolbachia release strategy and targeted dengue prevention measures.
#
# We are using the Mean Absolute Percentage Error (MAPE) metric because it measures the accuracy of the model's predictions as a percentage of the actual number of dengue cases. This makes it easier to interpret and communicate the model's performance to stakeholders. Moreover, MAPE provides a relative error measure, which is useful for comparing the accuracy of different models or evaluating the model on datasets with different scales. It is particularly suitable for this project because it allows for a more intuitive understanding of the model's prediction errors in relation to the actual number of dengue cases, which is crucial for effective resource allocation and dengue prevention efforts.
#
# By aiming to predict the number of dengue cases in the next 16 weeks and using the MAPE metric for model assessment, the NEA, with the support of the Ministry of Health as our secondary stakeholder, will enhance its readiness to address the dengue spread in Singapore. This will not only diminish the public health repercussions of dengue outbreaks but also guide the judicious distribution of resources towards proactive dengue prevention measures. Our project's predictive insights will also empower the Ministry of Health to take preemptive measures, ensuring the health and safety of the public while optimizing the use of resources.

# %% [markdown]
# **<u>[Cost Analysis](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC10021432/#:~:text=3.2-,Cost%2Deffectiveness%20of%20Wolbachia%20interventions,-Assuming%20steady%20state)</u> of Porject Wolbachia:**
#
# 1. **Effectiveness:** Wolbachia interventions were found to be cost-effective at 40% intervention effectiveness or above. The cost averted increases as the assumed intervention effectiveness of Wolbachia increases from 40% to 90%.
#
# 2. **Costs Averted Over Time:** At 40% intervention effectiveness, over US\\$329.40M would have been averted from 2010 to 2020. As the assumed intervention effectiveness increases from 40\% to 80\%, the estimated cost averted would also have increased to US\\$658.79M over the same period.
#
# 3. <u>[**DALYs Averted:**](https://www.who.int/data/gho/indicator-metadata-registry/imr-details/158#:~:text=Definition%3A-,One%20DALY%20represents%20the%20loss%20of%20the%20equivalent%20of%20one,health%20condition%20in%20a%20population.)</u> The costs per DALY averted decrease over time, indicating that the Wolbachia intervention becomes more cost-effective in terms of health outcomes over the years.

# %% [markdown]
# **Approach**:
#
# Assuming steady state costs of **US\\$22.7M** per year, and targetting 80% efficiency, we'll be using the formula ``(1-MAPE)X(Median cost averted) = steady-state cost X 1.8``. To calculate the net amount of cost averted. Median is being used as a measure of central tendency for the cost averted data because it is less sensitive to outliers or extreme values compared to the mean.

# %% [markdown]
# # <u>Part 1</u>

# %% [markdown]
# # Scraping Weather Data

# %% [markdown]
# We will be scraping historical daily weather data from all weather stations in Singapore

# %%
from bs4 import BeautifulSoup
import requests
import os
import pandas as pd
import io
import random
from time import sleep

# %%
url = "http://www.weather.gov.sg/climate-historical-daily/"
test = requests.get(url)
BeautifulSoup(test.text)
# Out:
# <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" lang="en-US">
# <![endif]--><!--[if IE 8]>
# <html class="ie ie8" lang="en-US">
# <![endif]--><!--[if !(IE 7) & !(IE 8)]><!--><html lang="en-US">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width" name="viewport"/>
# <!--<meta http-equiv="cache-control" content="max-age=0" />
# <meta http-equiv="cache-control" content="no-cache, no-store, must-revalidate" />
# <meta http-equiv="expires" content="0" />
# <meta http-equiv="expires" content="Tue, 01 Jan 1980 1:00:00 GMT" />
# <meta http-equiv="pragma" content="no-cache" />
# -->
# <!-- <meta http-equiv="cache-control" content="public, max-age=60, must-revalidate" /> -->
# <title>Historical Daily Records | </title>
# <link href="http://gmpg.org/xfn/11" rel="profile"/>
# <link href="http://www.weather.gov.sg/xmlrpc.php" rel="pingback"/>
# <link href="http://www.weather.gov.sg/wp-content/themes/wiptheme/lib/bootstrap/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/css/style.css" rel="stylesheet"/>
# <link href="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/css/non-responsive.css" rel="stylesheet"/>
# <link href="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/css/print.css" media="print" rel="stylesheet"/>
# <script src="http://www.weather.gov.sg/wp-content/themes/wiptheme/lib/jquery/jquery-3.6.0.min.js"></script>
# <script src="http://www.weather.gov.sg/wp-content/themes/wiptheme/lib/bootstrap/js/bootstrap.min.js"></script>
# <script src="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/js/global1.0.min.js"></script>
# <script src="http://www.weather.gov.sg/wp-content/themes/wiptheme/js/utils1.0.js"></script>
# <script src="http://www.weather.gov.sg/wp-content/themes/wiptheme/js/mobile.detect.js"></script>
# <script src="https://assets.wogaa.sg/scripts/wogaa.js"></script>
# </head>
# <body>
# <script type="text/javascript">
# $(function(){
# 	detectMobile();
# });
# function getCookieValue(name) {
#     var cookievalue = "";
#     var ca = document.cookie.split(";");
#     for(var i=0; i<ca.length; i++) {
# 		var c = ca[i].trim();
# 		c = c.replace(/\%20/g," ");
# 	  	if (c.indexOf(name)==0) {
# 	  	  	cookievalue = c.substring(name.length,c.length);
# 	 	}
#     }
#     return cookievalue;
# }
#
# function detectMobile(){
# 		var cookieName = "go_full_web=";
# 	var cookieValue = getCookieValue(cookieName);
# 	if(MobileEsp.isMobilePhone){
# 		if("yes" == cookieValue){
# 		}else{
# 			window.location.href = ('http://www.weather.gov.sg/mobile');
# 		}
# 	}
# }
# </script>
# </body><link href="http://www.weather.gov.sg/wp-content/themes/wiptheme/styles_resizer.css" rel="stylesheet"/> <header> <div class="container"> <div class="row logo-container"> <div class="col-xs-6"> <a href="http://www.weather.gov.sg/home/"><img alt="MSS" height="71" src="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/mss-logo.png" width="254"/></a> </div> <div class="col-xs-6"> <div class="sub-logo-container"> <a href="http://www.gov.sg"><img alt="Singapore Government" height="30" src="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/sg-gov-logo.jpg" width="220"/></a> </div> <div class="top-nav"> <ul class="list-inline donotresize"> <li class="donotresize"> <div id="controls"> <span class="donotresize" id="nowTextPercent"></span> <a class="selected donotresize" href="#" id="decrease" style="border-bottom:none;">A<sup>-</sup></a> <a class="donotresize" href="#" id="increase" style="border-bottom:none;">A<sup>+</sup></a> </div> </li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/about-contact-us/">Contact Us</a></li> <li class="donotresize"><form action="http://www.weather.gov.sg/" class="searchform" id="searchform" method="get" role="search">
# <div class="search-container">
# <button id="searchsubmit" type="submit"><img alt="icon-search" src="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/icon-search.png"/></button>
# <input id="s" name="s" placeholder="Search" type="text" value=""/>
# </div>
# </form> </li> </ul> </div> </div> </div><nav class="navbar navbar-inverse main-nav" role="navigation"> <ul class="nav navbar-nav"> <li class="donotresize"> <a class="dropdown-toggle donotresize" data-toggle="dropdown" href="#">Weather</a> <div class="dropdown-menu" role="menu"> <div class="row"> <div class="col-xs-2"> <div class="menu-group"> <h3 class="donotresize">Forecasts</h3> <ul class="donotresize"> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-forecast-2hrnowcast/">2-hr Nowcast</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-forecast-24hrforecast/">24-hr Forecast</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-forecast-4dayoutlook/">4-Day Outlook</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-fortnightly-outlook/">Fortnightly Outlook</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-forecast-monsoon-update/">Monsoon Update</a></li> </ul> </div> <div class="menu-group"> <h3 class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-world-forecast">World Forecasts </a></h3> </div> </div> <div class="col-xs-3"> <div class="menu-group"> <h3 class="donotresize">Marine Forecasts</h3> <ul class="donotresize"> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-marine-waves-height">Significant Wave</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-marine-wind-waves">Wind Wave</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-marine-swell">Swell</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-marine-surface-wind">Surface Wind</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-marine-shipping-bulletin">Marine Weather</a></li> </ul> </div> <div class="menu-group"> <h3 class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/lightning/" target="_blank">Lightning Information</a></h3> </div> </div> <div class="col-xs-3"> <div class="menu-group"> <h3 class="donotresize">Current Observations</h3> <ul class="donotresize"> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-currentobservations-rainfall/">Rainfall</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-currentobservations-temperature/">Temperature</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-currentobservations-relative-humidity/">Relative Humidity</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-currentobservations-wind/">Wind</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-currentobservations-visibility/">Visibility</a></li> </ul> </div> <div class="menu-group"> <h3 class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-uv">Ultraviolet Index (UVI) </a></h3> </div> </div> <div class="col-xs-2"> <div class="menu-group"> <h3 class="donotresize">Rain Areas</h3> <ul class="donotresize"> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-rain-area-50km">Singapore</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-rain-area-240km">240km Range</a></li> <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-rain-area-480km">480km Range</a></li> <li class="donotresize"> </li> <li class="donotresize"> </li> </ul> </div> <div class="menu-group"> <h3><a href="http://www.weather.gov.sg/heat-stress">Heat Stress</a></h3> </div> </div> <div class="col-xs-2"> <div class="menu-group"> <h3 class="donotresize">Satellite Images</h3> <ul class="donotres ...
#
#
# <h3>Learn</h3>
#
#
#
#
# <ul>
#
#
# <li class="pagination"><a href="../learn_overview/">Overview</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:120px"><a href="../learn_winds/">Winds</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:54px" ><a href="../learn_weather_systems/">Weather Systems</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:89px"><a href="../learn_phenomena/">Severe Weather</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:54px"><a href="../learn_climate/">Climate</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:96px"><a href="../learn_tidal/">Tides</a></li>
#
#
#
#
#
# </ul>
#
#
#
#
#
# <ul>
#
#
# <li class="pagination"><a href="../learn_atmosphere/">Earth's Atmosphere</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:54px"><a href="../learn_clouds/">Clouds</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:50px"><a href="../learn_observations/">Observing the Weather</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:56px"><a href="../forecasting-2/">Forecasting</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:81px"><a href="../learn-optical-effects/">Optical Effects</a></li>
#
#
#
#
# <li class="pagination" style="margin-left:54px"><a href="../learn_earthquakes/">Earthquakes and Volcanoes</a></li>
#
#
#
# </ul>
#
#
# --></p>
# <h3>Learn</h3>
# <ul>
# <li class="pagination"><a href="../learn_overview/">Overview</a></li>
# <li class="pagination" style="margin-left: 120px;"><a href="../learn_winds/">Winds</a></li>
# <li class="pagination" style="margin-left: 54px;"><a href="../learn_weather_systems/">Weather Systems</a></li>
# <li class="pagination" style="margin-left: 89px;"><a href="../learn_phenomena/">Severe Weather</a></li>
# <li class="pagination" style="margin-left: 54px;"><a href="../learn_climate/">Climate</a></li>
# <li class="pagination" style="margin-left: 96px;"><a href="../learn_tidal/">Tides</a></li>
# </ul>
# <ul>
# <li class="pagination"><a href="../learn_atmosphere/">Earth’s Atmosphere</a></li>
# <li class="pagination" style="margin-left: 54px;"><a href="../learn_clouds/">Clouds</a></li>
# <li class="pagination" style="margin-left: 50px;"><a href="../learn_observations/">Observing the Weather</a></li>
# <li class="pagination" style="margin-left: 56px;"><a href="../forecasting-2/">Forecasting</a></li>
# <li class="pagination" style="margin-left: 81px;"><a href="../learn-optical-effects/">Optical Effects</a></li>
# <li class="pagination" style="margin-left: 54px;"><a href="../learn_earthquakes/">Earthquakes and Volcanoes</a></li>
# </ul>
# <ul style="margin-top: 5px;">
# <li class="pagination"><a href="../learn-heat-stress/">Heat Stress</a></li>
# </ul>
# </div> </div> </div> </div> </li><li class="donotresize"> <a class="dropdown-toggle donotresize" data-toggle="dropdown" href="#">About MSS</a> <div class="dropdown-menu" id="unresize2" role="menu"> <div class="row"> <div class="col-xs-12"> <div class="menu-group"><h3>About</h3>
# <ul>
# <li class="pagination"><a href="/about-our-organisation/">Our Organisation</a></li>
# <li class="pagination" style="margin-left:110px"><a href="/about-our-organisation/#vision">Our Mission and Vision</a></li>
# <li class="pagination" style="margin-left:80px"><a href="/about-corporate-logo/">Corporate Logo</a></li>
# <li class="pagination" style="margin-left:100px"><a href="/home-all-news/?yearnews=2015">News</a></li>
# <li class="pagination" style="margin-left:105px"><a href="http://www.weather.gov.sg/visitus/">Visit Us</a></li>
# </ul>
# <ul>
# <li class="pagination"><a href="/about-our-organisation/#structure">Organisation Structure</a></li>
# <li class="pagination" style="margin-left:76px"><a href="/about-MSS-timeline/">Our History</a></li>
# <li class="pagination" style="margin-left:154px"><a href="/about-our-organisation/">Corporate Video</a></li>
# <li class="pagination" style="margin-left:95px"><a href="http://www.weather.gov.sg/about-career/">Careers</a></li>
# <li class="pagination" style="margin-left:89px"><a href="/about-contact-us/">Contact Us</a></li>
# </ul>
# </div> </div> </div> </div> <!-- / .dropdown-menu --> </li> <li class="donotresize"> <a class="dropdown-toggle donotresize" href="http://www.weather.gov.sg/faq/">FAQ</a> </li> </ul> </nav> <script type="text/javascript">$(function(){  $('#unresize1').find('*').addClass('donotresize');$('#unresize2').find('*').addClass('donotresize');})</script> </div></header><style>
# .world-region > span {
# 	position: absolute;
# 	display: block;
# 	width: 22px;
# 	height: 22px;
# 	background: url('http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/daily-hist-spot.png') center center no-repeat;
# 	cursor: pointer;
# }
# .world-region > span:hover,
# .world-region > span.active {
# 	background: url('http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/daily-hist-spot-active.png') center center no-repeat;
# }
# .popover {
# 	width: 200px;
# 	margin-left: 55px;
# }
# .popover .popover-content {
# 	width: 200px;
# 	padding-bottom: 5px;
# }
# </style>
# <link href="http://www.weather.gov.sg/wp-content/themes/wiptheme/jquery-ui/jquery-ui.css" rel="stylesheet"/>
# <script src="http://www.weather.gov.sg/wp-content/themes/wiptheme/jquery-ui/jquery-ui.js"></script>
# <!-- Main -->
# <div class="main">
# <div class="container">
# <div id="warningbarDetail"></div>
# <ol class="breadcrumb"> <li><a href="http://www.weather.gov.sg/home">Home</a></li> <li> <a class="dropdown-toggle" data-toggle="dropdown" href="#">Climate<span class="caret"></span></a> <ul class="dropdown-menu" role="menu"> <li><a href="http://www.weather.gov.sg/weather-forecast-24hrforecast">Weather</a></li> <li><a href="http://www.weather.gov.sg/warning-heavy-rain">Warnings and Advisories</a></li> </ul> </li> <li class="active">Historical Daily Records</li></ol> <!-- / .breadcrumb -->
# <div class="page-title">
# <h1>Historical Daily Records</h1>
# </div>
# <!-- / .page-title -->
# <p><i>Records will be updated by the 10<sup>th</sup> of the month</i></p>
# <div class="nav-tab-body">
# <div class="row tab-selector">
# <div class="col-xs-4">
# <div class="selectbox">
# <div class="btn-group">
# <button aria-expanded="false" class="btn btn-default dropdown-toggle" data-toggle="dropdown" id="cityname" type="button">Changi<span></span></button>
# <ul class="dropdown-menu long-dropdown" role="menu">
# <li><a href="#Admiralty" onclick="setYear('S104')">Admiralty</a></li><li><a href="#Admiralty West" onclick="setYear('S105')">Admiralty West</a></li><li><a href="#Ang Mo Kio" onclick="setYear('S109')">Ang Mo Kio</a></li><li><a href="#Boon Lay (East)" onclick="setYear('S86')">Boon Lay (East)</a></li><li><a href="#Boon Lay (West)" onclick="setYear('S63')">Boon Lay (West)</a></li><li><a href="#Botanic Garden" onclick="setYear('S120')">Botanic Garden</a></li><li><a href="#Buangkok" onclick="setYear('S55')">Buangkok</a></li><li><a href="#Bukit Panjang" onclick="setYear('S64')">Bukit Panjang</a></li><li><a href="#Bukit Timah" onclick="setYear('S90')">Bukit Timah</a></li><li><a href="#Buona Vista" onclick="setYear('S92')">Buona Vista</a></li><li><a href="#Chai Chee" onclick="setYear('S61')">Chai Chee</a></li><li><a href="#Changi" onclick="setYear('S24')">Changi</a></li><li><a href="#Choa Chu Kang (Central)" onclick="setYear('S114')">Choa Chu Kang (Central)</a></li><li><a href="#Choa Chu Kang (South)" onclick="setYear('S121')">Choa Chu Kang (South)</a></li><li><a href="#Choa Chu Kang (West)" onclick="setYear('S11')">Choa Chu Kang (West)</a></li><li><a href="#Clementi" onclick="setYear('S50')">Clementi</a></li><li><a href="#Dhoby Ghaut" onclick="setYear('S118')">Dhoby Ghaut</a></li><li><a href="#East Coast Parkway" onclick="setYear('S107')">East Coast Parkway</a></li><li><a href="#Jurong (East)" onclick="setYear('S39')">Jurong (East)</a></li><li><a href="#Jurong (North)" onclick="setYear('S101')">Jurong (North)</a></li><li><a href="#Jurong (West)" onclick="setYear('S44')">Jurong (West)</a></li><li><a href="#Jurong Island" onclick="setYear('S117')">Jurong Island</a></li><li><a href="#Jurong Pier" onclick="setYear('S33')">Jurong Pier</a></li><li><a href="#Kampong Bahru" onclick="setYear('S31')">Kampong Bahru</a></li><li><a href="#Kent Ridge" onclick="setYear('S71')">Kent Ridge</a></li><li><a href="#Khatib" onclick="setYear('S122')">Khatib</a></li><li><a href="#Kranji Reservoir" onclick="setYear('S66')">Kranji Reservoir</a></li><li><a href="#Lim Chu Kang" onclick="setYear('S112')">Lim Chu Kang</a></li><li><a href="#Lower Peirce Reservoir" onclick="setYear('S08')">Lower Peirce Reservoir</a></li><li><a href="#Macritchie Reservoir" onclick="setYear('S07')">Macritchie Reservoir</a></li><li><a href="#Mandai" onclick="setYear('S40')">Mandai</a></li><li><a href="#Marina Barrage" onclick="setYear('S108')">Marina Barrage</a></li><li><a href="#Marine Parade" onclick="setYear('S113')">Marine Parade</a></li><li><a href="#Newton" onclick="setYear('S111')">Newton</a></li><li><a href="#Nicoll Highway" onclick="setYear('S119')">Nicoll Highway</a></li><li><a href="#Pasir Panjang" onclick="setYear('S116')">Pasir Panjang</a></li><li><a href="#Pasir Ris (Central)" onclick="setYear('S94')">Pasir Ris (Central)</a></li><li><a href="#Pasir Ris (West)" onclick="setYear('S29')">Pasir Ris (West)</a></li><li><a href="#Paya Lebar" onclick="setYear('S06')">Paya Lebar</a></li><li><a href="#Pulau Ubin" onclick="setYear('S106')">Pulau Ubin</a></li><li><a href="#Punggol" onclick="setYear('S81')">Punggol</a></li><li><a href="#Queenstown" onclick="setYear('S77')">Queenstown</a></li><li><a href="#Seletar" onclick="setYear('S25')">Seletar</a></li><li><a href="#Semakau Island" onclick="setYear('S102')">Semakau Island</a></li><li><a href="#Sembawang" onclick="setYear('S80')">Sembawang</a></li><li><a href="#Sentosa Island" onclick="setYear('S60')">Sentosa Island</a></li><li><a href="#Serangoon" onclick="setYear('S36')">Serangoon</a></li><li><a href="#Serangoon North" onclick="setYear('S110')">Serangoon North</a></li><li><a href="#Simei" onclick="setYear('S84')">Simei</a></li><li><a href="#Somerset (Road)" onclick="setYear('S79')">Somerset (Road)</a></li><li><a href="#Tai Seng" onclick="setYear('S43')">Tai Seng</a></li><li><a href="#Tanjong Katong" onclick="setYear('S78')">Tanjong Katong</a></li><li><a href="#Tanjong Pagar" onclick="setYear('S72')">Tanjong Pagar</a></li><li><a hre ...
# </div>
# </div>
# </div>
# <div class="col-xs-3">
# <div class="selectbox" id="monthContainer">
# <div class="btn-group" id="monthDiv">
# <button aria-expanded="false" class="btn btn-default dropdown-toggle" data-toggle="dropdown" id="month" type="button">July<span></span></button>
# <ul class="dropdown-menu long-dropdown" role="menu">
# <li><a href="#January">January</a></li><li><a href="#February">February</a></li><li><a href="#March">March</a></li><li><a href="#April">April</a></li><li><a href="#May">May</a></li><li><a href="#June">June</a></li><li><a href="#July">July</a></li> </ul>
# </div>
# </div>
# </div>
# <div class="col-xs-3">
# <div class="selectbox" id="yearContainer">
# <div class="btn-group" id="yearDiv">
# <button aria-expanded="false" class="btn btn-default dropdown-toggle" data-toggle="dropdown" id="year" type="button">2023<span></span></button>
# <ul class="dropdown-menu long-dropdown" role="menu">
# <li><a href="#2023" onclick="setMonth(2023)">2023</a></li><li><a href="#2022" onclick="setMonth(2022)">2022</a></li><li><a href="#2021" onclick="setMonth(2021)">2021</a></li><li><a href="#2020" onclick="setMonth(2020)">2020</a></li><li><a href="#2019" onclick="setMonth(2019)">2019</a></li><li><a href="#2018" onclick="setMonth(2018)">2018</a></li><li><a href="#2017" onclick="setMonth(2017)">2017</a></li><li><a href="#2016" onclick="setMonth(2016)">2016</a></li><li><a href="#2015" onclick="setMonth(2015)">2015</a></li><li><a href="#2014" onclick="setMonth(2014)">2014</a></li><li><a href="#2013" onclick="setMonth(2013)">2013</a></li><li><a href="#2012" onclick="setMonth(2012)">2012</a></li><li><a href="#2011" onclick="setMonth(2011)">2011</a></li><li><a href="#2010" onclick="setMonth(2010)">2010</a></li><li><a href="#2009" onclick="setMonth(2009)">2009</a></li><li><a href="#2008" onclick="setMonth(2008)">2008</a></li><li><a href="#2007" onclick="setMonth(2007)">2007</a></li><li><a href="#2006" onclick="setMonth(2006)">2006</a></li><li><a href="#2005" onclick="setMonth(2005)">2005</a></li><li><a href="#2004" onclick="setMonth(2004)">2004</a></li><li><a href="#2003" onclick="setMonth(2003)">2003</a></li><li><a href="#2002" onclick="setMonth(2002)">2002</a></li><li><a href="#2001" onclick="setMonth(2001)">2001</a></li><li><a href="#2000" onclick="setMonth(2000)">2000</a></li><li><a href="#1999" onclick="setMonth(1999)">1999</a></li><li><a href="#1998" onclick="setMonth(1998)">1998</a></li><li><a href="#1997" onclick="setMonth(1997)">1997</a></li><li><a href="#1996" onclick="setMonth(1996)">1996</a></li><li><a href="#1995" onclick="setMonth(1995)">1995</a></li><li><a href="#1994" onclick="setMonth(1994)">1994</a></li><li><a href="#1993" onclick="setMonth(1993)">1993</a></li><li><a href="#1992" onclick="setMonth(1992)">1992</a></li><li><a href="#1991" onclick="setMonth(1991)">1991</a></li><li><a href="#1990" onclick="setMonth(1990)">1990</a></li><li><a href="#1989" onclick="setMonth(1989)">1989</a></li><li><a href="#1988" onclick="setMonth(1988)">1988</a></li><li><a href="#1987" onclick="setMonth(1987)">1987</a></li><li><a href="#1986" onclick="setMonth(1986)">1986</a></li><li><a href="#1985" onclick="setMonth(1985)">1985</a></li><li><a href="#1984" onclick="setMonth(1984)">1984</a></li><li><a href="#1983" onclick="setMonth(1983)">1983</a></li><li><a href="#1982" onclick="setMonth(1982)">1982</a></li><li><a href="#1981" onclick="setMonth(1981)">1981</a></li><li><a href="#1980" onclick="setMonth(1980)">1980</a></li> </ul>
# </div>
# </div>
# </div>
# <input class="btn btn-default donotresize" id="display" name="display" onclick="doDisplay();" type="button" value="Display"/>
# </div>
# <div class="row">
# <div class="col-xs-12">
# <div class="map-container-lg">
# <div class="world-region">
# <span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Paya Lebar&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Paya Lebar" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Macritchie Reservoir&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Macritchie Reservoir" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Lower Peirce Reservoir&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Lower Peirce Reservoir" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Jurong (North)&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Jurong (North)" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Semakau Island&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Semakau Island" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Admiralty&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Admiralty" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Admiralty West&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Admiralty West" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Pulau Ubin&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Pulau Ubin" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;East Coast Parkway&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="East Coast Parkway" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Marina Barrage&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Marina Barrage" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Ang Mo Kio&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Ang Mo Kio" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Choa Chu Kang (West)&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Choa Chu Kang (West)" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Serangoon North&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Serangoon North" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Newton&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Newton" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Lim Chu Kang&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Lim Chu Kang" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Marine Parade&lt;/strong&gt;&lt;/p &gt;" data-placement="top" data-toggle="popover" data-trigger="hover" id="Marine Parade" onclick="setText(this);" style="display:none;"></span><span class="sgr points" data-content="&lt;p&gt;&lt;strong&gt;Choa Chu Kang (Central)&lt;/strong&gt;&lt;/p &gt;" data-placement="top"  ...
# <!-- / End Popover Content -->
# </div>
# <img alt="map of weather stations" height="561" id="basemap" src="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/sg-map.jpg" width="998"/>
# </div>
# <div class="box-shadow-lg"></div>
# </div>
# </div>
# <!-- / .row -->
# <div class="table-container" id="tableContainer"></div>
# <div class="row">
# <div class="col-xs-10">
# <div class="report-block report-info">
# <h3></h3>
# <p>The availability of observational data and duration of records vary across stations. Manual observations were gradually replaced by automated meteorological instruments from 2009. Click <a href="../wp-content/uploads/2022/06/Station_Records.pdf" rel="noopener" target="_blank" title="Station Records">here</a> for the list of stations, weather parameters and periods of records available.<br/>
# <!-- / .collapse-wrapper --></p>
# </div>
# <p><!-- / .report-block --></p>
# <div class="report-block report-info">
# <h3></h3>
# <p><!-- / .collapse-wrapper --></p>
# </div>
# <p><!-- / .report-block --></p>
# <div class="report-block report-info">
# <h3></h3>
# <p><!-- / .collapse-wrapper --></p>
# </div>
# <p><!-- / .report-block --></p>
# </div>
# </div>
# <div class="related-block">
# <div class="row">
# <div class="col-xs-3">
# <h4>Related Information</h4>
# <ul>
# <li><a href="../climate-historical-extremes/" title="Historical Extremes">Historical Extremes</a></li>
# <li><a href="../climate-climate-of-singapore/" title="Climatology of Singapore">Climate of Singapore</a></li>
# <li><a href="../climate-detailed-view/" title="Climate Maps">Climate Maps</a></li>
# </ul>
# </div>
# <div class="col-xs-9">
# <h4>Learn About</h4>
# <ul>
# <li><a href="../learn_climate/">Difference between weather and climate</a></li>
# <li><a href="../learn_climate/#climate4">Function of a climate station</a></li>
# <li><a href="../learn_climate/#climate3">Climate variability and climate change</a></li>
# </ul>
# </div>
# </div>
# </div>
# <!-- .entry-content -->
# <footer class="entry-meta">
# </footer><!-- .entry-meta -->
# </div>
# </div>
# </div>
# <script type="text/javascript">
#
#
# 	function doDisplay(){
# 		var cityname = $('#cityname').text();
#       	var month = $('#month').text();
#         var year = $('#year').text();
#         changePoint(cityname);
# 		viewClimate(cityname,month,year);
# 		}
#
# 	/* function setText(continentName,countryName,cityName){
# 		$('#continentName').text(continentName);
# 		$('#continentName').append("<span></span>");
# 		$('#countryName').text(countryName);
# 		$('#countryName').append("<span></span>");
# 		$('#cityName').text(cityName);
# 		$('#cityName').append("<span></span>");
# 		viewClimate(continentName,countryName,cityName);
# 		} */
# 	function changePoint(cityname){
# 		var arr=document.getElementsByClassName("points");
# 		resetPoints(arr);
# 		for(var i=0;i<arr.length;i++){
# 			if(arr[i].id == cityname){
# 				arr[i].style.backgroundImage="url(http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/daily-hist-spot-active.png)";
# 			}
# 		}
# 	}
#
# 	function resetPoints(arr){
# 		for(var i=0;i<arr.length;i++){
# 			arr[i].style.backgroundImage="url(http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/daily-hist-spot.png)";
# 		}
# 	}
#
# 	function setText(sid){
# 		var month = $('#month').text();
#         var year = $('#year').text();
#         var cityname=sid.id;
#         var arr=document.getElementsByName("points");
#         for(var i=0;i<arr.length;i++){
# 			if(arr[i]==document.getElementById(cityname)){
# 				arr[i].style.backgroundImage="url(http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/daily-hist-spot-active.png)";
# 			}else{
# 				arr[i].style.backgroundImage="url(http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/daily-hist-spot.png)";
# 			}
#         }
#         document.getElementById('cityname').innerHTML=cityname+"<span></span>";
#         viewClimate(cityname,month,year);
# 	}
#
#     function viewClimate(cityname,month,year){
#         //$(".world-region > span").removeClass("active");
#        // $("span[name='"+month+"']").addClass("active");
#         var redirectUrl = "http://www.weather.gov.sg/weather-world-forecast";
# 		var url = "http://www.weather.gov.sg/wp-content/themes/wiptheme/page-functions/functions-climate-historical-daily-records.php";
# 		var data = {cityname:cityname,month:month,year:year,redirectUrl:redirectUrl};
# 		var options = {data:data, url:url};
# 		callAjax(options,showTempDetail);
# 	}
#
# 		function showTempDetail(data){
# 			$('#temp').remove();
# 			$("#tableContainer").prepend(data);
# 		}
#
# /* 		$('.dropdown-toggle').click(function (){
# 				$(this).attr("aria-expanded","true");
# 				$(this).parent().addClass("open");
# 			}); */
#
# 	function setMonth(year){
# 		var url = "http://www.weather.gov.sg/wp-content/themes/wiptheme/page-functions/functions-climate-historical-daily-months.php";
# 		var cityname = $('#cityname').text();
# 		var data = {year:year,cityname:cityname};
# 		var options={data:data,url:url};
# 		callAjax(options,showMonthDetail);
# 	}
#
# 	function showMonthDetail(data){
# 		$('#monthDiv').remove();
# 		$("#monthContainer").prepend(data);
# 		/* $('.dropdown-toggle').click(function (){
# 			$(this).attr("aria-expanded","true");
# 			$(this).parent().addClass("open");
# 		}); */
# 		$('.selectbox .dropdown-menu li a').click(function(e) {
# 			e.preventDefault();
# 			var select_val = $(this).text();
# 			$(this).closest('.btn-group').find('.btn').html(select_val + '<span></span>');
# 		});
# 	}
#
# 	function setYear(stationCode){
# 		var url = "http://www.weather.gov.sg/wp-content/themes/wiptheme/page-functions/functions-climate-historical-daily-year.php";
# 		var data={stationCode:stationCode};
# 		var options={data:data,url:url};
# 		callAjax(options,showYearDetail);
# 	}
#
# 	function showYearDetail(data){
# 		$('#yearDiv').remove();
# 		$("#yearContainer").prepend(data);
# 		var year=$('#year').html().replace('<span></span>','');
# 		if(year!="&nbsp;"){
# 			setMonth(year);
# 		}else{
# 			setMonth(0);
# 		}
# 		/* $('.dropdown-toggle').click(function (){
# 			$(this).attr("aria-expanded","true");
# 			$(this).parent().addClass("open");
# 		}); */
# 		$('.selectbox .dropdown-menu li a').click(function(e) {
# 			e.preventDefault();
# 			var select_val = $(this).text();
# 			$(this).closest('.btn-group').find('.btn').html(select_val + '<span></span>');
# 		});
# 	}
#
#     </script>
# <script type="text/javascript">
#
#     function calculatePosition(basemapImg,latitude,longitude){
# 		  /* var map_latitude_top = 1.499;
# 		  var map_longitude_left = 103.572;
# 		  var map_latitude_bottom = 1.149;
# 		  var map_longitude_right = 104.118; */
# 		  var map_latitude_top = 1.475;
# 		  var map_longitude_left = 103.559;
# 		  var map_latitude_bottom = 1.142;
# 		  var map_longitude_right = 104.149;
# 			var width_calibration = 20720;
# 			var height_calibration = 246;
# 			var zoom_level_height = 200;
# 			var zoom_level_width = 200;
# 			var imgWidth  = basemapImg.width;
# 			var imgHeight = basemapImg.height;
# 			var scale		  = imgWidth/100;
# 			var map_latitude_total = map_latitude_top - map_latitude_bottom;
# 			var map_longitude_total = map_longitude_right - map_longitude_left;
#
# 			var positions = new Object();
#
# 			//positions[0] = ((Number(longitude)+0.015)*zoom_level_height-height_calibration)*scale+'px';
# 			//positions[1] = (latitude*zoom_level_width-width_calibration)*scale+'px';
# 			positions[0] = (map_latitude_top-latitude)/map_latitude_total*imgHeight+'px';
# 		  positions[1] = (longitude-map_longitude_left)/map_longitude_total*imgWidth+'px';
# 			return positions;
# 	}
#
# 	function setPosition(){
# 		var basemapImg = document.getElementById('basemap');
# 		var stations=new Array();
# 		stations[0]={station_code:"S06",
# 										station_name:"Paya Lebar",
# 										longitude:"103.90373333",
# 										latitude:"1.35713333"};stations[1]={station_code:"S07",
# 										station_name:"Macritchie Reservoir",
# 										longitude:"103.83390000",
# 										latitude:"1.34180000"};stations[2]={station_code:"S08",
# 										station_name:"Lower Peirce Reservoir",
# 										longitude:"103.82706667",
# 										latitude:"1.37003333"};stations[3]={station_code:"S101",
# 										station_name:"Jurong (North)",
# 										longitude:"103.71340000",
# 										latitude:"1.35053333"};stations[4]={station_code:"S102",
# 										station_name:"Semakau Island",
# 										longitude:"103.76571667",
# 										latitude:"1.19016667"};stations[5]={station_code:"S104",
# 										station_name:"Admiralty",
# 										longitude:"103.78538333",
# 										latitude:"1.44386667"};stations[6]={station_code:"S105",
# 										station_name:"Admiralty West",
# 										longitude:"103.79525000",
# 										latitude:"1.45816667"};stations[7]={station_code:"S106",
# 										station_name:"Pulau Ubin",
# 										longitude:"103.96730000",
# 										latitude:"1.41680000"};stations[8]={station_code:"S107",
# 										station_name:"East Coast Parkway",
# 										longitude:"103.96198333",
# 										latitude:"1.31331667"};stations[9]={station_code:"S108",
# 										station_name:"Marina Barrage",
# 										longitude:"103.87030000",
# 										latitude:"1.27991667"};stations[10]={station_code:"S109",
# 										station_name:"Ang Mo Kio",
# 										longitude:"103.85001667",
# 										latitude:"1.37926667"};stations[11]={station_code:"S11",
# 										station_name:"Choa Chu Kang (West)",
# 										longitude:"103.69373333",
# 										latitude:"1.37425000"};stations[12]={station_code:"S110",
# 										station_name:"Serangoon North",
# 										longitude:"103.87076667",
# 										latitude:"1.36531667"};stations[13]={station_code:"S111",
# 										station_name:"Newton",
# 										longitude:"103.83650000",
# 										latitude:"1.31055000"};stations[14]={station_code:"S112",
# 										station_name:"Lim Chu Kang",
# 										longitude:"103.70173333",
# 										latitude:"1.43880000"};stations[15]={station_code:"S113",
# 										station_name:"Marine Parade",
# 										longitude:"103.91121667",
# 										latitude:"1.30501667"};stations[16]={station_code:"S114",
# 										station_name:"Choa Chu Kang (Central)",
# 										longitude:"103.73810000",
# 										latitude:"1.38208333"};stations[17]={station_code:"S115",
# 										station_name:"Tuas South",
# 										longitude:"103.61840000",
# 										latitude:"1.29380000"};stations[18]={station_code:"S116",
# 										station_name:"Pasir Panjang",
# 										longitude:"103.75450000",
# 										latitude:"1.28235000"};stations[19]={station_code:"S117",
# 										station_name:"Jurong Island",
# 										longitude:"103.67900000",
# 										latitude:"1.25600000"};stations[20]={station_code:"S118",
# 										station_name:"Dhoby Ghaut",
# 										longitude:"103.84606667",
# 										latitude:"1.29940000"};stations[21]={station_code:"S119",
# 										station_name:"Nicoll Highway",
# 										longitude:"103.86218333",
# 										latitude:"1.29503333"};stations[22]={station_code:"S120",
# 										station_name:"Botanic Garden",
# 										longitude:"103.81801667",
# 										latitude:"1.30871667"};stations[23]={station_code:"S121",
# 										station_name:"Choa Chu Kang (South)",
# 										longitude:"103.71140000",
# 										latitude:"1.38580000"};stations[24]={station_code:"S122",
# 										station_name:"Khatib",
# 										longitude:"103.82513333",
# 										latitude:"1.41725000"};stations[25]={station_code:"S123",
# 										station_name:"Whampoa",
# 										longitude:"103.85765000",
# 										latitude:"1.32141667"};stations[26]={station_code:"S23",
# 										station_name:"Tengah",
# 										longitude:"103.71166667",
# 										latitude:"1.38500000"};stations[27]={station_code:"S24",
# 										station_name:"Changi",
# 										longitude:"103.98226667",
# 										latitude:"1.36776667"};stations[28]={station_code:"S25",
# 										station_name:"Seletar",
# 										longitude:"103.86500000",
# 										latitude:"1.41666667"};stations[29]={station_code:"S29",
# 										station_name:"Pasir Ris (West)",
# 										longitude:"103.94133333",
# 										latitude:"1.38650000"};stations[30]={station_code:"S31",
# 										station_name:"Kampong Bahru",
# 										longitude:"103.82816667",
# 										latitude:"1.27431667"};stations[31]={station_code:"S33",
# 										station_name:"Jurong Pier",
# 										longitude:"103.70986667",
# 										latitude:"1.30818333"};stations[32]={station_code:"S35",
# 										station_name:"Ulu Pandan",
# 										longitude:"103.75498333",
# 										latitude:"1.33246667"};stations[33]={station_code:"S36",
# 										station_name:"Serangoon",
# 										longitude:"103.86615000",
# 										latitude:"1.33765000"};stations[34]={station_code:"S39",
# 										station_name:"Jurong (East)",
# 										longitude:"103.73675000",
# 										latitude:"1.32516667"};stations[35]={station_code:"S40",
# 										station_name:"Mandai",
# 										longitude:"103.78320000",
# 										latitude:"1.40665000"};stations[36]={station_code:"S43",
# 										station_name:"Tai Seng",
# 										longitude:"103.88816667",
# 										latitude:"1.34061667"};stations[37]={station_code:"S44",
# 										station_name:"Jurong (West)",
# 										longitude:"103.68333333",
# 										latitude:"1.34523333"};stations[38]={station_code:"S46",
# 										station_name:"Upper Thomson",
# 										longitude:"103.81078333",
# 										latitude:"1.34155000"};stations[39]={station_code:"S50",
# 										station_name:"Clementi",
# 										longitude:"103.77611667",
# 										latitude:"1.33178333"};stations[40]={station_code:"S55",
# 										station_name:"Buangkok",
# 										longitude:"103.88603333",
# 										latitude:"1.38358333"};stations[41]={station_code:"S60",
# 										station_name:"Sentosa Island",
# 										longitude:"103.82753333",
# 										latitude:"1.25040000"};stations[42]={station_code:"S61",
# 										station_name:"Chai Chee",
# 										longitude:"103.92065000",
# 										latitude:"1.32710000"};stations[43]={station_code:"S63",
# 										station_name:"Boon Lay (West)",
# 										longitude:"103.70416667",
# 										latitude:"1.32746667"};stations[44]={station_code:"S64",
# 										station_name:"Bukit Panjang",
# 										longitude:"103.76066667",
# 										latitude:"1.38228333"};stations[45]={station_code:"S66",
# 										station_name:"Kranji Reservoir",
# 										longitude:"103.73601667",
# 										latitude:"1.43866667"};stations[46]={station_code:"S69",
# 										station_name:"Upper Peirce Reservoir",
# 										longitude:"103.80463333",
# 										latitude:"1.37035000"};stations[47]={station_code:"S71",
# 										station_name:"Kent Ridge",
# 										longitude:"103.78150000",
# 										latitude:"1.29230000"};stations[48]={station_code:"S72",
# 										station_name:"Tanjong Pagar",
# 										longitude:"103.84823333",
# 										latitude:"1.27388333"};stations[49]={station_code:"S77",
# 										station_name:"Queenstown",
# 										longitude:"103.81268333",
# 										latitude:"1.29360000"};stations[50]={station_code:"S78",
# 										station_name:"Tanjong Katong",
# 										longitude:"103.89066667",
# 										latitude:"1.30703333"};stations[51]={station_code:"S79",
# 										station_name:"Somerset (Road)",
# 										longitude:"103.83720000",
# 										latitude:"1.30040000"};stations[52]={station_code:"S80",
# 										station_name:"Sembawang",
# 										longitude:"103.82000000",
# 										latitude:"1.42500000"};stations[53]={station_code:"S81",
# 										station_name:"Punggol",
# 										longitude:"103.90948333",
# 										latitude:"1.40285000"};stations[54]={station_code:"S82",
# 										station_name:"Tuas West",
# 										longitude:"103.63520000",
# 										latitude:"1.32480000"};stations[55]={station_code:"S84",
# 										station_name:"Simei",
# 										longitude:"103.94405000",
# 										latitude:"1.34428333"};stations[56]={station_code:"S86",
# 										station_name:"Boon Lay (East)",
# 										longitude:"103.72046667",
# 										latitude:"1.32686667"};stations[57]={station_code:"S88",
# 										station_name:"Toa Payoh",
# 										longitude:"103.85150000",
# 										latitude:"1.34171667"};stations[58]={station_code:"S89",
# 										station_name:"Tuas",
# 										longitude:"103.66131667",
# 										latitude:"1.31985000"};stations[59]={station_code:"S90",
# 										station_name:"Bukit Timah",
# 										longitude:"103.81928333",
# 										latitude:"1.31910000"};stations[60]={station_code:"S91",
# 										station_name:"Yishun",
# 										longitude:"103.83061667",
# 										latitude:"1.42993333"};stations[61]={station_code:"S92",
# 										station_name:"Buona Vista",
# 										longitude:"103.78875000",
# 										latitude:"1.28408333"};stations[62]={station_code:"S94",
# 										station_name:"Pasir Ris (Central)",
# 										longitude:"103.94898333",
# 										latitude:"1.36793333"};		for(var i=0;i<stations.length;i++){
# 			var str=document.getElementById(stations[i]['station_name']);
# 			var longitude=stations[i]['longitude'];
# 			var latitude=stations[i]['latitude'];
# 			var positions=calculatePosition(basemapImg,latitude,longitude);
# 			str.style.top = positions[0];
# 	    	str.style.left = positions[1];
# 	    	str.style.display = 'block';
# 		}
# 	}
#
#
# function showWarningbar(){
#     var url = "http://www.weather.gov.sg/wp-content/themes/wiptheme/page-functions/functions-ajax-warningbar.php";
# 	var options={url:url};
# 	callAjax(options,showWarningbarCallback);
# }
#
# function showWarningbarCallback(data){
#     $('#warningbarDetail').html('');
#     var warningData = JSON.parse(data);
#     var detail = "";
#     var moduleLink = "";
# 	if (warningData.length  > 0) {
# 	    detail += "<!-- Warning Bar -->";
# 	    for (var i = 0; i < warningData.length; i++) {
# 		    if (warningData[i].warnings.length > 0) {
# 			    for (var j = 0; j < warningData[i].warnings.length; j++) {
# 			    	if(warningData[i].warnings[j].show) {
#
# 				        if(warningData[i].warnings[j].module == 'H') {
# 							moduleLink = "http://www.weather.gov.sg/warning-heavy-rain/";
# 						} else if(warningData[i].warnings[j].module == 'V') {
# 							moduleLink = "http://www.weather.gov.sg/warning-volcanic-eruption/";
# 						} else if(warningData[i].warnings[j].module == 'R') {
# 							moduleLink = "http://www.weather.gov.sg/warning-regional-seismic-information/";
# 						} else if(warningData[i].warnings[j].module == 'T') {
# 							moduleLink = "http://www.weather.gov.sg/warning-tropical-cyclone-information/";
# 						} else if(warningData[i].warnings[j].module == 'Z') {
# 							moduleLink = "http://www.weather.gov.sg/warning-haze-satellite-image/";
# 						} else if(warningData[i].warnings[j].module == 'D') {
# 							moduleLink = "http://www.weather.gov.sg/heat-stress/";
# 						} else if(warningData[i].warnings[j].module == 'S') {
# 							moduleLink = "javascript:void(0)";
# 						} else if(warningData[i].warnings[j].module == 'O') {
# 							moduleLink = "http://www.weather.gov.sg/other-warnings/";
# 						}
# 						if(warningData[i].warnings[j].module == 'S') {
#
# 				        detail = detail + "<div class=\"warning-bar2 bg-danger\" style=\"background: #75C7EA;\">"
# 										+ " 	<div class=\"warning-text\">"
# 										+ "      <ul class=\"list-inline\">"
# 										+ "          <li><b>" + warningData[i].warnings[j].content + "</b></li>"
# 										+ "      </ul>"
# 										+ "		<a href=\"javascript:void(0)\" class=\"close\" title=\"Close\" onclick=\"setBannerCookies('" + warningData[i].warnings[j].id + "');\"><span class=\"glyphicon glyphicon-remove\"></span></a>"
# 										+ "	</div>"
# 										+ "</div>";
# 						} else {
# 				        detail = detail + "<div class=\"warning-bar2 bg-danger\">"
# 										+ "	<div class=\"warning\">"
# 										+ "		<img src='http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/icon-exclamation.png' width='26' height='26' alt='excl'>Warning"
# 										+ "	</div>"
# 										+ " 	<div class=\"warning-text\">"
# 										+ "      <ul class=\"list-inline\">"
# 										+ "          <li><a href=\"" + moduleLink + "\">" + warningData[i].warnings[j].content + "</a></li>"
# 										+ "      </ul>"
# 										+ "		<a href=\"javascript:void(0)\" class=\"close\" title=\"Close\" onclick=\"setBannerCookies('" + warningData[i].warnings[j].id + "');\"><span class=\"glyphicon glyphicon-remove\"></span></a>"
# 										+ "	</div>"
# 										+ "</div>";
# 						}
# 			    	}
# 			    }
# 		    }
# 		    if (warningData[i].advs.length > 0) {
# 		        for (var j = 0; j < warningData[i].advs.length; j++) {
# 		        	if(warningData[i].advs[j].show) {
#
# 			            if(warningData[i].advs[j].module == 'H') {
# 							moduleLink = "http://www.weather.gov.sg/warning-heavy-rain/";
# 						} else if(warningData[i].advs[j].module == 'V') {
# 							moduleLink = "http://www.weather.gov.sg/warning-volcanic-eruption/";
# 						} else if(warningData[i].advs[j].module == 'R') {
# 							moduleLink = "http://www.weather.gov.sg/warning-regional-seismic-information/";
# 						} else if(warningData[i].advs[j].module == 'T') {
# 							moduleLink = "http://www.weather.gov.sg/warning-tropical-cyclone-information/";
# 						} else if(warningData[i].advs[j].module == 'Z') {
# 							moduleLink = "http://www.weather.gov.sg/warning-haze-satellite-image/";
# 						}  else if(warningData[i].warnings[j].module == 'D') {
# 							moduleLink = "http://www.weather.gov.sg/heat-stress/";
# 						}else if(warningData[i].advs[j].module == 'S') {
# 							moduleLink = "javascript:void(0)";
# 						} else if(warningData[i].advs[j].module == 'O') {
# 							moduleLink = "http://www.weather.gov.sg/other-warnings/";
# 						}
# 				        detail +=  "<div class=\"warning-bar2 bg-warning\">"
# 								+ "	<div class=\"warning\">"
# 								+ "		<img src='http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/icon-exclamation.png' width='26' height='26' alt='excl'>Advisory"
# 								+ "	</div>"
# 								+ " 	<div class=\"warning-text\">"
# 								+ "      <ul class=\"list-inline\">"
# 								+ "          <li><a href=\"" + moduleLink + "\">" +warningData[i].advs[j].content+ "</a></li>"
# 								+ "      </ul>"
# 								+ "		<a href=\"javascript:void(0)\" class=\"close\" title=\"Close\" onclick=\"setBannerCookies('" + warningData[i].advs[j].id + "');\"><span class=\"glyphicon glyphicon-remove\"></span></a>"
# 								+ "	</div>"
# 								+ "</div>";
# 		        	}
# 			    }
# 		    }
#
# 	    }
# 		detail +=  "<!-- / .warning-bar -->";
# 	} else {
# 		//if("1" == 1) {
# 		//	detail +=  "<!-- Information Update Message -->"
# 		//				+ "<div class=\"err-message bg-success\">"
# 		//				+ "<p><strong>Update:</strong></p>"
# 		//				+ "<p>There are currently no Warnings or Advisories.</p>"
# 		//				+ "		<a href=\"javascript:void(0)\" class=\"close\" title=\"Close\" onclick=\"setBannerCookies('noWarnings');\"><span class=\"glyphicon glyphicon-remove\"></span></a>"
# 		//				+ "</div>"
# 		//				+ "<!-- / End Information Update Message -->";
# 		//}
# 	}
#
# 	$('#warningbarDetail').html(detail);
#
# 	$('.warning-bar2 .close').click(function () {
# 		$(this).closest('.warning-bar2').fadeOut();
# 	});
#
# 	$('.err-message .close').click(function () {
# 		$(this).closest('.err-message').fadeOut();
# 	});
# }
# 	$(function() {
# 		setPosition();
# 		doDisplay();
# 		showWarningbar();
# 	});
#
# 	setInterval('showWarningbar()',1000*60*5);
# 	//window.onload=setPosition;
# 	</script>
# <!--
# 	</div> #main .wrapper
# 	<footer id="colophon" role="contentinfo">
# 		<div class="site-info">
# 						<a href="http://wordpress.org/" title="Semantic Personal Publishing Platform">Proudly powered by WordPress</a>
# 		</div>.site-info
# 	</footer> #colophon
# </div> #page -->
# <!-- Footer -->
# <footer>
# <div class="footer-link-list">
# <div class="container">
# <div class="row">
# <div class="col-xs-2">
# <ul class="list-unstyled donotresize">
# <li class="donotresize">About MSS</li>
# <ul>
# <li class="donotresize" style="text-transform: none;"><a class="donotresize" href="/about-our-organisation/">Our Organisation</a></li>
# <li class="donotresize"><a class="donotresize" href="/about-our-organisation/#structure">Organisation Structure</a></li>
# <li class="donotresize"><a class="donotresize" href="/about-our-organisation/#vision">Our Mission and Vision</a></li>
# <li class="donotresize"><a class="donotresize" href="/about-corporate-logo/">Corporate Logo</a></li>
# <li class="donotresize"><a class="donotresize" href="/about-MSS-timeline/">Our History</a></li>
# <li class="donotresize"><a class="donotresize" href="/about-our-organisation/">Corporate Video</a></li>
# <li class="donotresize"><a class="donotresize" href="/home-all-news/?yearnews=2015">News</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/about-career/">Careers</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/visitus/">Visit Us</a></li>
# <li class="donotresize"><a class="donotresize" href="/about-contact-us/">Contact Us</a></li>
# </ul>
# </ul>
# </div>
# <div class="col-xs-2">
# <ul class="list-unstyled donotresize">
# <li class="donotresize">Weather</li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-forecast-24hrforecast/">Forecasts</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-currentobservations-rainfall/">Current Observations</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-rain-area-50km/">Rain Areas</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-satellite-geo-stationary/">Satellite Images</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/lightning/" target="_blank">Lightning Information</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-marine-waves-height/">Marine Forecasts</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-world-forecast/">World Forecasts</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-uv/">UV Index</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/heat-stress/">Heat Stress</a></li>
# <!--                                <li><a href="http://www.weather.gov.sg/weather-significant-events/">Significant Weather Events</a></li>-->
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/weather-astronomical-and-tidal-information-today/">Astronomical Data and Tides</a></li>
# </ul>
# </div>
# <div class="col-xs-2">
# <ul class="list-unstyled donotresize">
# <li class="donotresize">Climate</li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/climate-historical-daily/">Historical Daily Records</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/climate-historical-extremes/">Historical Extremes</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/climate-world-climate/">World Climate</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/climate-trends/">Climate Maps</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/climate-climate-of-singapore/">Climate Of Singapore</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/climate-past-climate-trends/">Past Climate Trends</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/climate-annual-climate-reports/">Annual Reports</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/climate-el-la/">El NiÃ±o / La NiÃ±a Status</a></li>
# </ul>
# </div>
# <div class="col-xs-2">
# <ul class="list-unstyled donotresize">
# <li class="donotresize">Warnings and Advisories</li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/warning-heavy-rain/">Heavy Rain Warning</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/warning-haze-satellite-image/">Haze Information</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/warning-tropical-cyclone-information/">Tropical Cyclone Information</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/warning-regional-seismic-information/">Regional Earthquakes/Tsunami</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/warning-volcanic-eruption/">Regional Volcanic Eruptions</a></li>
# </ul>
# </div>
# <div class="col-xs-2">
# <ul class="list-unstyled donotresize">
# <li class="donotresize">Learn</li>
# <ul>
# <li class="donotresize"><a class="donotresize" href="../learn_overview/">Overview</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_atmosphere/">Earth’s Atmosphere</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_winds/">Winds</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_clouds/">Clouds</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_weather_systems/">Weather Systems</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_observations/">Observing the Weather</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_phenomena/">Severe Weather</a></li>
# <li class="donotresize"><a class="donotresize" href="../forecasting-2/">Forecasting</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_climate/">Climate</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn-optical-effects/">Optical Effects</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_tidal/">Tides</a></li>
# <li class="donotresize"><a class="donotresize" href="../learn_earthquakes/">Earthquakes and Volcanoes</a></li>
# </ul>
# </ul>
# </div>
# <div class="col-xs-2">
# <ul class="list-unstyled donotresize">
# <li class="donotresize">Our Centres</li>
# <li class="donotresize"><a class="donotresize" href="http://ccrs.weather.gov.sg/">Centre for Climate Research Singapore</a></li>
# <li class="donotresize"><a class="donotresize" href="http://asmc.asean.org/" target="_blank">ASEAN Specialised Meteorological Centre</a></li>
# </ul>
# <ul class="list-unstyled donotresize">
# <li class="donotresize">Our Associate sites</li>
# <li class="donotresize"><a class="donotresize" href="http://www.nea.gov.sg/">National Environment Agency</a></li>
# <li class="donotresize"><a class="donotresize" href="https://www.mse.gov.sg">Ministry of Sustainability and the Environment</a></li>
# </ul>
# <!--                            <ul class="list-unstyled donotresize">-->
# <!--                                <li class="donotresize">OUR SPECIALISED SERVICES</li>-->
# <!--                                <!-- <li><a href="--><!--">Aviation Weather</a></li> -->--&gt;
# <!--                            </ul>-->
# </div>
# </div>
# </div>
# </div>
# <!-- / .footer-link-list -->
# <div class="footer-foot">
# <div class="container">
# <div class="row">
# <div class="col-xs-6">
# <ul class="list-inline text-left donotresize" style="width:max-content">
# <li class="donotresize"><a class="donotresize" href="https://www.weather.gov.sg/wip-login.php" target="_blank">Login</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/terms-of-use">Terms of Use</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/privacy">Privacy policy</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/rate-this-website">Rate this site</a></li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/supported-browsers">Supported Browsers</a></li>
# <li class="donotresize"><a class="donotresize" href="https://www.tech.gov.sg/report_vulnerability">Report Vulnerability</a></li>
# </ul>
# </div>
# <div class="col-xs-6">
# <ul class="list-inline text-right share-link-group donotresize">
# <li class="donotresize">Follow us on</li>
# <li class="donotresize"><a class="donotresize" href="http://www.weather.gov.sg/rss-feed"><img alt="RSS" height="21" src="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/icon-rss.png" width="22"/></a></li>
# <li class="donotresize"><a class="donotresize" href="https://twitter.com/MetServiceSG" target="_blank"><img alt="Twitter" height="21" src="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/icon-twitter.png" width="22"/></a></li>
# <li class="donotresize"><a class="donotresize" href="https://www.youtube.com/user/MetServiceSG" target="_blank"><img alt="Youtube" height="23" src="http://www.weather.gov.sg/wp-content/themes/wiptheme/assets/img/icon-youtube.png" width="23"/></a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- / .footer-foot -->
# </footer>
# <script type="text/javascript">
#             /* <![CDATA[ */
#            document.querySelectorAll("ul.nav-menu").forEach(
#                ulist => {
#                     if (ulist.querySelectorAll("li").length == 0) {
#                         ulist.style.display = "none";
#
#                                             }
#                 }
#            );
#             /* ]]> */
#         </script>
# <script src="http://www.weather.gov.sg/wp-content/themes/wiptheme/js/function_resizer.js"></script>
# <script type="text/javascript">
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','//www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-59001161-2', 'auto');
#   ga('send', 'pageview');
#
# </script>
# </html>

# %%
# Finding the dropdown menu containing station names and codes
dropdown_menu = BeautifulSoup(test.text).find('ul', class_='dropdown-menu long-dropdown')

# Initialize a dictionary to store station names and codes
station_info = {}

# Loop through each <a> tag within the dropdown menu
for link in dropdown_menu.find_all('a'):
    station_name = link.get_text()
    station_code = link['onclick'].split("setYear('")[1].split("')")[0]
    station_info[station_code] = station_name

# Print the extracted station names and codes
for code, name in station_info.items():
    print(f"{code} : {name}")
# Out:
# S104 : Admiralty
# S105 : Admiralty West
# S109 : Ang Mo Kio
# S86 : Boon Lay (East)
# S63 : Boon Lay (West)
# S120 : Botanic Garden
# S55 : Buangkok
# S64 : Bukit Panjang
# S90 : Bukit Timah
# S92 : Buona Vista
# S61 : Chai Chee
# S24 : Changi
# S114 : Choa Chu Kang (Central)
# S121 : Choa Chu Kang (South)
# S11 : Choa Chu Kang (West)
# S50 : Clementi
# S118 : Dhoby Ghaut
# S107 : East Coast Parkway
# S39 : Jurong (East)
# S101 : Jurong (North)
# S44 : Jurong (West)
# S117 : Jurong Island
# S33 : Jurong Pier
# S31 : Kampong Bahru
# S71 : Kent Ridge
# S122 : Khatib
# S66 : Kranji Reservoir
# S112 : Lim Chu Kang
# S08 : Lower Peirce Reservoir
# S07 : Macritchie Reservoir
# S40 : Mandai
# S108 : Marina Barrage
# S113 : Marine Parade
# S111 : Newton
# S119 : Nicoll Highway
# S116 : Pasir Panjang
# S94 : Pasir Ris (Central)
# S29 : Pasir Ris (West)
# S06 : Paya Lebar
# S106 : Pulau Ubin
# S81 : Punggol
# S77 : Queenstown
# S25 : Seletar
# S102 : Semakau Island
# S80 : Sembawang
# S60 : Sentosa Island
# S36 : Serangoon
# S110 : Serangoon North
# S84 : Simei
# S79 : Somerset (Road)
# S43 : Tai Seng
# S78 : Tanjong Katong
# S72 : Tanjong Pagar
# S23 : Tengah
# S88 : Toa Payoh
# S89 : Tuas
# S115 : Tuas South
# S82 : Tuas West
# S35 : Ulu Pandan
# S69 : Upper Peirce Reservoir
# S46 : Upper Thomson
# S123 : Whampoa
# S91 : Yishun

# %%
output_folder = "../data"  # Folder where downloaded files will be saved
combined_csv_filename = "combined_data.csv"  # Combined CSV file name

# Ensure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

base_url_template = "http://www.weather.gov.sg/files/dailydata/DAILYDATA_{}_{:04d}{:02d}.csv"

# Initialize an empty DataFrame to store the combined data
combined_df = pd.DataFrame()

for station_id, station_name in station_info.items():
    for year in range(2010, 2024):  # Adjust the range as needed
        for month in range(1, 13):
            csv_url = base_url_template.format(station_id, year, month)
            csv_filename = os.path.join(output_folder, f"{station_id}_{year:04d}_{month:02d}.csv")
            
            # Download the CSV file
            csv_response = requests.get(csv_url)
            if csv_response.status_code == 200:
                # with open(csv_filename, "wb") as csv_file:
                #     csv_file.write(csv_response.content)
                #     print(f"Downloaded: {csv_filename}")
                csv_content = io.BytesIO(csv_response.content)
                
                # Read the downloaded CSV file into a DataFrame
                temp_df = pd.read_csv(csv_content, encoding='ISO-8859-1')
                
                # Concatenate the temporary DataFrame with the combined DataFrame
                combined_df = pd.concat([combined_df, temp_df], ignore_index=True)

                print(f"Downloaded and processed: {station_name}_{year:04d}_{month:02d}")
            else:
                print(f"Failed to download: {csv_filename}. Status code:", csv_response.status_code)

            sleep(random.uniform(0.0005, 2))

# Save the combined DataFrame as a single CSV file
combined_csv_filename = os.path.join(output_folder, "combined_data.csv")
combined_df.to_csv(combined_csv_filename, index=False)

print(f"Combined data saved to '{combined_csv_filename}'.")
# Out:
# Downloaded and processed: Admiralty_2010_01
# Downloaded and processed: Admiralty_2010_02
# Downloaded and processed: Admiralty_2010_03
# Downloaded and processed: Admiralty_2010_04
# Downloaded and processed: Admiralty_2010_05
# Downloaded and processed: Admiralty_2010_06
# Downloaded and processed: Admiralty_2010_07
# Downloaded and processed: Admiralty_2010_08
# Downloaded and processed: Admiralty_2010_09
# Downloaded and processed: Admiralty_2010_10
# Downloaded and processed: Admiralty_2010_11
# Downloaded and processed: Admiralty_2010_12
# Downloaded and processed: Admiralty_2011_01
# Downloaded and processed: Admiralty_2011_02
# Downloaded and processed: Admiralty_2011_03
# Downloaded and processed: Admiralty_2011_04
# Downloaded and processed: Admiralty_2011_05
# Downloaded and processed: Admiralty_2011_06
# Downloaded and processed: Admiralty_2011_07
# Downloaded and processed: Admiralty_2011_08
# Downloaded and processed: Admiralty_2011_09
# Downloaded and processed: Admiralty_2011_10
# Downloaded and processed: Admiralty_2011_11
# Downloaded and processed: Admiralty_2011_12
# Downloaded and processed: Admiralty_2012_01
# Downloaded and processed: Admiralty_2012_02
# Downloaded and processed: Admiralty_2012_03
# Downloaded and processed: Admiralty_2012_04
# Downloaded and processed: Admiralty_2012_05
# Downloaded and processed: Admiralty_2012_06
# Downloaded and processed: Admiralty_2012_07
# Downloaded and processed: Admiralty_2012_08
# Downloaded and processed: Admiralty_2012_09
# Downloaded and processed: Admiralty_2012_10
# Downloaded and processed: Admiralty_2012_11
# Downloaded and processed: Admiralty_2012_12
# Downloaded and processed: Admiralty_2013_01
# Downloaded and processed: Admiralty_2013_02
# Downloaded and processed: Admiralty_2013_03
# Downloaded and processed: Admiralty_2013_04
# Downloaded and processed: Admiralty_2013_05
# Downloaded and processed: Admiralty_2013_06
# Downloaded and processed: Admiralty_2013_07
# Downloaded and processed: Admiralty_2013_08
# Downloaded and processed: Admiralty_2013_09
# Downloaded and processed: Admiralty_2013_10
# Downloaded and processed: Admiralty_2013_11
# Downloaded and processed: Admiralty_2013_12
# Downloaded and processed: Admiralty_2014_01
# Downloaded and processed: Admiralty_2014_02
# Downloaded and processed: Admiralty_2014_03
# Downloaded and processed: Admiralty_2014_04
# Downloaded and processed: Admiralty_2014_05
# Downloaded and processed: Admiralty_2014_06
# Downloaded and processed: Admiralty_2014_07
# Downloaded and processed: Admiralty_2014_08
# Failed to download: outputcsv_files/S104_2014_09.csv. Status code: 404
# Downloaded and processed: Admiralty_2014_10
# Downloaded and processed: Admiralty_2014_11
# Downloaded and processed: Admiralty_2014_12
# Downloaded and processed: Admiralty_2015_01
# Downloaded and processed: Admiralty_2015_02
# Downloaded and processed: Admiralty_2015_03
# Downloaded and processed: Admiralty_2015_04
# Downloaded and processed: Admiralty_2015_05
# Downloaded and processed: Admiralty_2015_06
# Downloaded and processed: Admiralty_2015_07
# Downloaded and processed: Admiralty_2015_08
# Downloaded and processed: Admiralty_2015_09
# Downloaded and processed: Admiralty_2015_10
# Downloaded and processed: Admiralty_2015_11
# Downloaded and processed: Admiralty_2015_12
# Downloaded and processed: Admiralty_2016_01
# Downloaded and processed: Admiralty_2016_02
# Downloaded and processed: Admiralty_2016_03
# Downloaded and processed: Admiralty_2016_04
# Downloaded and processed: Admiralty_2016_05
# Downloaded and processed: Admiralty_2016_06
# Downloaded and processed: Admiralty_2016_07
# Downloaded and processed: Admiralty_2016_08
# Downloaded and processed: Admiralty_2016_09
# Downloaded and processed: Admiralty_2016_10
# Downloaded and processed: Admiralty_2016_11
# Downloaded and processed: Admiralty_2016_12
# Downloaded and processed: Admiralty_2017_01
# Downloaded and processed: Admiralty_2017_02
# Downloaded and processed: Admiralty_2017_03
# Downloaded and processed: Admiralty_2017_04
# Downloaded and processed: Admiralty_2017_05
# Downloaded and processed: Admiralty_2017_06
# Downloaded and processed: Admiralty_2017_07
# Downloaded and processed: Admiralty_2017_08
# Downloaded and processed: Admiralty_2017_09
# Downloaded and processed: Admiralty_2017_10
# Downloaded and processed: Admiralty_2017_11
# Downloaded and processed: Admiralty_2017_12
# Downloaded and processed: Admiralty_2018_01
# Downloaded and processed: Admiralty_2018_02
# Downloaded and processed: Admiralty_2018_03
# Downloaded and processed: Admiralty_2018_04
# Downloaded and processed: Admiralty_2018_05
# Downloaded and processed: Admiralty_2018_06
# Downloaded and processed: Admiralty_2018_07
# Downloaded and processed: Admiralty_2018_08
# Downloaded and processed: Admiralty_2018_09
# Downloaded and processed: Admiralty_2018_10
# Downloaded and processed: Admiralty_2018_11
# Downloaded and processed: Admiralty_2018_12
# Downloaded and processed: Admiralty_2019_01
# Downloaded and processed: Admiralty_2019_02
# Downloaded and processed: Admiralty_2019_03
# Downloaded and processed: Admiralty_2019_04
# Downloaded and processed: Admiralty_2019_05
# Downloaded and processed: Admiralty_2019_06
# Downloaded and processed: Admiralty_2019_07
# Downloaded and processed: Admiralty_2019_08
# Downloaded and processed: Admiralty_2019_09
# Downloaded and processed: Admiralty_2019_10
# Downloaded and processed: Admiralty_2019_11
# Downloaded and processed: Admiralty_2019_12
# Downloaded and processed: Admiralty_2020_01
# Downloaded and processed: Admiralty_2020_02
# Downloaded and processed: Admiralty_2020_03
# Downloaded and processed: Admiralty_2020_04
# Downloaded and processed: Admiralty_2020_05
# Downloaded and processed: Admiralty_2020_06
# Downloaded and processed: Admiralty_2020_07
# Downloaded and processed: Admiralty_2020_08
# Downloaded and processed: Admiralty_2020_09
# Downloaded and processed: Admiralty_2020_10
# Downloaded and processed: Admiralty_2020_11
# Downloaded and processed: Admiralty_2020_12
# Downloaded and processed: Admiralty_2021_01
# Downloaded and processed: Admiralty_2021_02
# Downloaded and processed: Admiralty_2021_03
# Downloaded and processed: Admiralty_2021_04
# Downloaded and processed: Admiralty_2021_05
# Downloaded and processed: Admiralty_2021_06
# Downloaded and processed: Admiralty_2021_07
# Downloaded and processed: Admiralty_2021_08
# Downloaded and processed: Admiralty_2021_09
# Downloaded and processed: Admiralty_2021_10
# Downloaded and processed: Admiralty_2021_11
# Downloaded and processed: Admiralty_2021_12
# Downloaded and processed: Admiralty_2022_01
# Downloaded and processed: Admiralty_2022_02
# Downloaded and processed: Admiralty_2022_03
# Downloaded and processed: Admiralty_2022_04
# Downloaded and processed: Admiralty_2022_05
# Downloaded and processed: Admiralty_2022_06
# Downloaded and processed: Admiralty_2022_07
# Downloaded and processed: Admiralty_2022_08
# Downloaded and processed: Admiralty_2022_09
# Downloaded and processed: Admiralty_2022_10
# Downloaded and processed: Admiralty_2022_11
# Downloaded and processed: Admiralty_2022_12
# Downloaded and processed: Admiralty_2023_01
# Downloaded and processed: Admiralty_2023_02
# Downloaded and processed: Admiralty_2023_03
# Downloaded and processed: Admiralty_2023_04
# Downloaded and processed: Admiralty_2023_05
# Downloaded and processed: Admiralty_2023_06
# Downloaded and processed: Admiralty_2023_07
# Failed to download: outputcsv_files/S104_2023_08.csv. Status code: 404
# Failed to download: outputcsv_files/S104_2023_09.csv. Status code: 404
# Failed to download: outputcsv_files/S104_2023_10.csv. Status code: 404
# Failed to download: outputcsv_files/S104_2023_11.csv. Status code: 404
# Failed to download: outputcsv_files/S104_2023_12.csv. Status code: 404
# Downloaded and processed: Admiralty West_2010_01
# Downloaded and processed: Admiralty West_2010_02
# Downloaded and processed: Admiralty West_2010_03
# Downloaded and processed: Admiralty West_2010_04
# Downloaded and processed: Admiralty West_2010_05
# Downloaded and processed: Admiralty West_2010_06
# Downloaded and processed: Admiralty West_2010_07
# Downloaded and processed: Admiralty West_2010_08
# Downloaded and processed: Admiralty West_2010_09
# Downloaded and processed: Admiralty West_2010_10
# Downloaded and processed: Admiralty West_2010_11
# Downloaded and processed: Admiralty West_2010_12
# Downloaded and processed: Admiralty West_2011_01
# Downloaded and processed: Admiralty West_2011_02
# Downloaded and processed: Admiralty West_2011_03
# Downloaded and processed: Admiralty West_2011_04
# Downloaded and processed: Admiralty West_2011_05
# Downloaded and processed: Admiralty West_2011_06
# Downloaded and processed: Admiralty West_2011_07
# Downloaded and processed: Admiralty West_2011_08
# Downloaded and processed: Admiralty West_2011_09
# Downloaded and processed: Admiralty West_2011_10
# Downloaded and processed: Admiralty West_2011_11
# Downloaded and processed: Admiralty West_2011_12
# Downloaded and processed: Admiralty West_2012_01
# Downloaded and processed: Admiralty West_2012_02
# Downloaded and processed: Admiralty West_2012_03
# Downloaded and processed: Admiralty West_2012_04
# Downloaded and processed: Admiralty West_2012_05
# Downloaded and processed: Admiralty West_2012_06
# Downloaded and processed: Admiralty West_2012_07
# Downloaded and processed: Admiralty West_2012_08
# Downloaded and processed: Admiralty West_2012_09
# Downloaded and processed: Admiralty West_2012_10
# Downloaded and processed: Admiralty West_2012_11
# Downloaded and processed: Admiralty West_2012_12
# Downloaded and processed: Admiralty West_2013_01
# Downloaded and processed: Admiralty West_2013_02
# Downloaded and processed: Admiralty West_2013_03
# Downloaded and processed: Admiralty West_2013_04
# Downloaded and processed: Admiralty West_2013_05
# Downloaded and processed: Admiralty West_2013_06
# Downloaded and processed: Admiralty West_2013_07
# Downloaded and processed: Admiralty West_2013_08
# Downloaded and processed: Admiralty West_2013_09
# Downloaded and processed: Admiralty West_2013_10
# Downloaded and processed: Admiralty West_2013_11
# Downloaded and processed: Admiralty West_2013_12
# Downloaded and processed: Admiralty West_2014_01
# Downloaded and processed: Admiralty West_2014_02
# Downloaded and processed: Admiralty West_2014_03
# Downloaded and processed: Admiralty West_2014_04
# Downloaded and processed: Admiralty West_2014_05
# Downloaded and processed: Admiralty West_2014_06
# Downloaded and processed: Admiralty West_2014_07
# Downloaded and processed: Admiralty West_2014_08
# Downloaded and processed: Admiralty West_2014_09
# Downloaded and processed: Admiralty West_2014_10
# Downloaded and processed: Admiralty West_2014_11
# Downloaded and processed: Admiralty West_2014_12
# Downloaded and processed: Admiralty West_2015_01
# Downloaded and processed: Admiralty West_2015_02
# Downloaded and processed: Admiralty West_2015_03
# Downloaded and processed: Admiralty West_2015_04
# Downloaded and processed: Admiralty West_2015_05
# Downloaded and processed: Admiralty West_2015_06
# Downloaded and processed: Admiralty West_2015_07
# Downloaded and processed: Admiralty West_2015_08
# Downloaded and processed: Admiralty West_2015_09
# Downloaded and processed: Admiralty West_2015_10
# Downloaded and processed: Admiralty West_2015_11
# Downloaded and processed: Admiralty West_2015_12
# Downloaded and processed: Admiralty West_2016_01
# Downloaded and processed: Admiralty West_2016_02
# Downloaded and processed: Admiralty West_2016_03
# Downloaded and processed: Admiralty West_2016_04
# Downloaded and processed: Admiralty West_2016_05
# Downloaded and processed: Admiralty West_2016_06
# Downloaded and processed: Admiralty West_2016_07
# Downloaded and processed: Admiralty West_2016_08
# Downloaded and processed: Admiralty West_2016_09
# Failed to download: outputcsv_files/S105_2016_10.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2016_11.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2016_12.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_01.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_02.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_03.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_04.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_05.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_06.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_07.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_08.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_09.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_10.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_11.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2017_12.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2018_01.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2018_02.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2018_03.csv. Status code: 404
# Downloaded and processed: Admiralty West_2018_04
# Downloaded and processed: Admiralty West_2018_05
# Downloaded and processed: Admiralty West_2018_06
# Downloaded and processed: Admiralty West_2018_07
# Downloaded and processed: Admiralty West_2018_08
# Downloaded and processed: Admiralty West_2018_09
# Downloaded and processed: Admiralty West_2018_10
# Downloaded and processed: Admiralty West_2018_11
# Downloaded and processed: Admiralty West_2018_12
# Downloaded and processed: Admiralty West_2019_01
# Downloaded and processed: Admiralty West_2019_02
# Downloaded and processed: Admiralty West_2019_03
# Downloaded and processed: Admiralty West_2019_04
# Downloaded and processed: Admiralty West_2019_05
# Downloaded and processed: Admiralty West_2019_06
# Downloaded and processed: Admiralty West_2019_07
# Downloaded and processed: Admiralty West_2019_08
# Downloaded and processed: Admiralty West_2019_09
# Downloaded and processed: Admiralty West_2019_10
# Downloaded and processed: Admiralty West_2019_11
# Downloaded and processed: Admiralty West_2019_12
# Downloaded and processed: Admiralty West_2020_01
# Downloaded and processed: Admiralty West_2020_02
# Downloaded and processed: Admiralty West_2020_03
# Downloaded and processed: Admiralty West_2020_04
# Failed to download: outputcsv_files/S105_2020_05.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2020_06.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2020_07.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2020_08.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2020_09.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2020_10.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2020_11.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2020_12.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_01.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_02.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_03.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_04.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_05.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_06.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_07.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_08.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_09.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_10.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_11.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2021_12.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_01.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_02.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_03.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_04.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_05.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_06.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_07.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_08.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_09.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_10.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_11.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2022_12.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_01.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_02.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_03.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_04.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_05.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_06.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_07.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_08.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_09.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_10.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_11.csv. Status code: 404
# Failed to download: outputcsv_files/S105_2023_12.csv. Status code: 404
# Downloaded and processed: Ang Mo Kio_2010_01
# Downloaded and processed: Ang Mo Kio_2010_02
# Downloaded and processed: Ang Mo Kio_2010_03
# Downloaded and processed: Ang Mo Kio_2010_04
# Downloaded and processed: Ang Mo Kio_2010_05
# Downloaded and processed: Ang Mo Kio_2010_06
# Downloaded and processed: Ang Mo Kio_2010_07
# Downloaded and processed: Ang Mo Kio_2010_08
# Downloaded and processed: Ang Mo Kio_2010_09
# Downloaded and processed: Ang Mo Kio_2010_10
# Downloaded and processed: Ang Mo Kio_2010_11
# Downloaded and processed: Ang Mo Kio_2010_12
# Downloaded and processed: Ang Mo Kio_2011_01
# Downloaded and processed: Ang Mo Kio_2011_02
# Downloaded and processed: Ang Mo Kio_2011_03
# Downloaded and processed: Ang Mo Kio_2011_04
# Downloaded and processed: Ang Mo Kio_2011_05
# Downloaded and processed: Ang Mo Kio_2011_06
# Downloaded and processed: Ang Mo Kio_2011_07
# Downloaded and processed: Ang Mo Kio_2011_08
# Downloaded and processed: Ang Mo Kio_2011_09
# Downloaded and processed: Ang Mo Kio_2011_10
# Downloaded and processed: Ang Mo Kio_2011_11
# Downloaded and processed: Ang Mo Kio_2011_12
# Downloaded and processed: Ang Mo Kio_2012_01
# Downloaded and processed: Ang Mo Kio_2012_02
# Downloaded and processed: Ang Mo Kio_2012_03
# Downloaded and processed: Ang Mo Kio_2012_04
# Downloaded and processed: Ang Mo Kio_2012_05
# Downloaded and processed: Ang Mo Kio_2012_06
# Downloaded and processed: Ang Mo Kio_2012_07
# Downloaded and processed: Ang Mo Kio_2012_08
# Downloaded and processed: Ang Mo Kio_2012_09
# Downloaded and processed: Ang Mo Kio_2012_10
# Downloaded and processed: Ang Mo Kio_2012_11
# Downloaded and processed: Ang Mo Kio_2012_12
# Downloaded and processed: Ang Mo Kio_2013_01
# Downloaded and processed: Ang Mo Kio_2013_02
# Downloaded and processed: Ang Mo Kio_2013_03
# Downloaded and processed: Ang Mo Kio_2013_04
# Downloaded and processed: Ang Mo Kio_2013_05
# Downloaded and processed: Ang Mo Kio_2013_06
# Downloaded and processed: Ang Mo Kio_2013_07
# Downloaded and processed: Ang Mo Kio_2013_08
# Downloaded and processed: Ang Mo Kio_2013_09
# Downloaded and processed: Ang Mo Kio_2013_10
# Downloaded and processed: Ang Mo Kio_2013_11
# Downloaded and processed: Ang Mo Kio_2013_12
# Downloaded and processed: Ang Mo Kio_2014_01
# Downloaded and processed: Ang Mo Kio_2014_02
# Downloaded and processed: Ang Mo Kio_2014_03
# Downloaded and processed: Ang Mo Kio_2014_04
# Downloaded and processed: Ang Mo Kio_2014_05
# Downloaded and processed: Ang Mo Kio_2014_06
# Downloaded and processed: Ang Mo Kio_2014_07
# Downloaded and processed: Ang Mo Kio_2014_08
# Downloaded and processed: Ang Mo Kio_2014_09
# Downloaded and processed: Ang Mo Kio_2014_10
# Downloaded and processed: Ang Mo Kio_2014_11
# Downloaded and processed: Ang Mo Kio_2014_12
# Downloaded and processed: Ang Mo Kio_2015_01
# Downloaded and processed: Ang Mo Kio_2015_02
# Downloaded and processed: Ang Mo Kio_2015_03
# Downloaded and processed: Ang Mo Kio_2015_04
# Downloaded and processed: Ang Mo Kio_2015_05
# Downloaded and processed: Ang Mo Kio_2015_06
# Downloaded and processed: Ang Mo Kio_2015_07
# Downloaded and processed: Ang Mo Kio_2015_08
# Downloaded and processed: Ang Mo Kio_2015_09
# Downloaded and processed: Ang Mo Kio_2015_10
# Downloaded and processed: Ang Mo Kio_2015_11
# Downloaded and processed: Ang Mo Kio_2015_12
# Downloaded and processed: Ang Mo Kio_2016_01
# Downloaded and processed: Ang Mo Kio_2016_02
# Downloaded and processed: Ang Mo Kio_2016_03
# Downloaded and processed: Ang Mo Kio_2016_04
# Downloaded and processed: Ang Mo Kio_2016_05
# Downloaded and processed: Ang Mo Kio_2016_06
# Downloaded and processed: Ang Mo Kio_2016_07
# Downloaded and processed: Ang Mo Kio_2016_08
# Downloaded and processed: Ang Mo Kio_2016_09
# Downloaded and processed: Ang Mo Kio_2016_10
# Downloaded and processed: Ang Mo Kio_2016_11
# Downloaded and processed: Ang Mo Kio_2016_12
# Downloaded and processed: Ang Mo Kio_2017_01
# Downloaded and processed: Ang Mo Kio_2017_02
# Downloaded and processed: Ang Mo Kio_2017_03
# Downloaded and processed: Ang Mo Kio_2017_04
# Downloaded and processed: Ang Mo Kio_2017_05
# Downloaded and processed: Ang Mo Kio_2017_06
# Downloaded and processed: Ang Mo Kio_2017_07
# Downloaded and processed: Ang Mo Kio_2017_08
# Downloaded and processed: Ang Mo Kio_2017_09
# Downloaded and processed: Ang Mo Kio_2017_10
# Downloaded and processed: Ang Mo Kio_2017_11
# Downloaded and processed: Ang Mo Kio_2017_12
# Downloaded and processed: Ang Mo Kio_2018_01
# Downloaded and processed: Ang Mo Kio_2018_02
# Downloaded and processed: Ang Mo Kio_2018_03
# Downloaded and processed: Ang Mo Kio_2018_04
# Downloaded and processed: Ang Mo Kio_2018_05
# Downloaded and processed: Ang Mo Kio_2018_06
# Downloaded and processed: Ang Mo Kio_2018_07
# Downloaded and processed: Ang Mo Kio_2018_08
# Downloaded and processed: Ang Mo Kio_2018_09
# Downloaded and processed: Ang Mo Kio_2018_10
# Downloaded and processed: Ang Mo Kio_2018_11
# Downloaded and processed: Ang Mo Kio_2018_12
# Downloaded and processed: Ang Mo Kio_2019_01
# Downloaded and processed: Ang Mo Kio_2019_02
# Downloaded and processed: Ang Mo Kio_2019_03
# Downloaded and processed: Ang Mo Kio_2019_04
# Downloaded and processed: Ang Mo Kio_2019_05
# Downloaded and processed: Ang Mo Kio_2019_06
# Downloaded and processed: Ang Mo Kio_2019_07
# Downloaded and processed: Ang Mo Kio_2019_08
# Downloaded and processed: Ang Mo Kio_2019_09
# Downloaded and processed: Ang Mo Kio_2019_10
# Downloaded and processed: Ang Mo Kio_2019_11
# Downloaded and processed: Ang Mo Kio_2019_12
# Downloaded and processed: Ang Mo Kio_2020_01
# Downloaded and processed: Ang Mo Kio_2020_02
# Downloaded and processed: Ang Mo Kio_2020_03
# Downloaded and processed: Ang Mo Kio_2020_04
# Downloaded and processed: Ang Mo Kio_2020_05
# Downloaded and processed: Ang Mo Kio_2020_06
# Downloaded and processed: Ang Mo Kio_2020_07
# Downloaded and processed: Ang Mo Kio_2020_08
# Downloaded and processed: Ang Mo Kio_2020_09
# Downloaded and processed: Ang Mo Kio_2020_10
# Downloaded and processed: Ang Mo Kio_2020_11
# Downloaded and processed: Ang Mo Kio_2020_12
# Downloaded and processed: Ang Mo Kio_2021_01
# Downloaded and processed: Ang Mo Kio_2021_02
# Downloaded and processed: Ang Mo Kio_2021_03
# Downloaded and processed: Ang Mo Kio_2021_04
# Downloaded and processed: Ang Mo Kio_2021_05
# Downloaded and processed: Ang Mo Kio_2021_06
# Downloaded and processed: Ang Mo Kio_2021_07
# Downloaded and processed: Ang Mo Kio_2021_08
# Downloaded and processed: Ang Mo Kio_2021_09
# Downloaded and processed: Ang Mo Kio_2021_10
# Downloaded and processed: Ang Mo Kio_2021_11
# Downloaded and processed: Ang Mo Kio_2021_12
# Downloaded and processed: Ang Mo Kio_2022_01
# Downloaded and processed: Ang Mo Kio_2022_02
# Downloaded and processed: Ang Mo Kio_2022_03
# Downloaded and processed: Ang Mo Kio_2022_04
# Downloaded and processed: Ang Mo Kio_2022_05
# Downloaded and processed: Ang Mo Kio_2022_06
# Downloaded and processed: Ang Mo Kio_2022_07
# Downloaded and processed: Ang Mo Kio_2022_08
# Downloaded and processed: Ang Mo Kio_2022_09
# Downloaded and processed: Ang Mo Kio_2022_10
# Downloaded and processed: Ang Mo Kio_2022_11
# Downloaded and processed: Ang Mo Kio_2022_12
# Downloaded and processed: Ang Mo Kio_2023_01
# Downloaded and processed: Ang Mo Kio_2023_02
# Downloaded and processed: Ang Mo Kio_2023_03
# Downloaded and processed: Ang Mo Kio_2023_04
# Downloaded and processed: Ang Mo Kio_2023_05
# Downloaded and processed: Ang Mo Kio_2023_06
# Downloaded and processed: Ang Mo Kio_2023_07
# Failed to download: outputcsv_files/S109_2023_08.csv. Status code: 404
# Failed to download: outputcsv_files/S109_2023_09.csv. Status code: 404
# Failed to download: outputcsv_files/S109_2023_10.csv. Status code: 404
# Failed to download: outputcsv_files/S109_2023_11.csv. Status code: 404
# Failed to download: outputcsv_files/S109_2023_12.csv. Status code: 404
# Downloaded and processed: Boon Lay (East)_2010_01
# Downloaded and processed: Boon Lay (East)_2010_02
# Downloaded and processed: Boon Lay (East)_2010_03
# Downloaded and processed: Boon Lay (East)_2010_04
# Downloaded and processed: Boon Lay (East)_2010_05
# Downloaded and processed: Boon Lay (East)_2010_06
# Downloaded and processed: Boon Lay (East)_2010_07
# Downloaded and processed: Boon Lay (East)_2010_08
# Downloaded and processed: Boon Lay (East)_2010_09
# Downloaded and processed: Boon Lay (East)_2010_10
# Downloaded and processed: Boon Lay (East)_2010_11
# Downloaded and processed: Boon Lay (East)_2010_12
# Downloaded and processed: Boon Lay (East)_2011_01
# Downloaded and processed: Boon Lay (East)_2011_02
# Downloaded and processed: Boon Lay (East)_2011_03
# Downloaded and processed: Boon Lay (East)_2011_04
# Downloaded and processed: Boon Lay (East)_2011_05
# Downloaded and processed: Boon Lay (East)_2011_06
# Downloaded and processed: Boon Lay (East)_2011_07
# Downloaded and processed: Boon Lay (East)_2011_08
# Downloaded and processed: Boon Lay (East)_2011_09
# Downloaded and processed: Boon Lay (East)_2011_10
# Downloaded and processed: Boon Lay (East)_2011_11
# Downloaded and processed: Boon Lay (East)_2011_12
# Downloaded and processed: Boon Lay (East)_2012_01
# Downloaded and processed: Boon Lay (East)_2012_02
# Downloaded and processed: Boon Lay (East)_2012_03
# Downloaded and processed: Boon Lay (East)_2012_04
# Downloaded and processed: Boon Lay (East)_2012_05
# Downloaded and processed: Boon Lay (East)_2012_06
# Downloaded and processed: Boon Lay (East)_2012_07
# Downloaded and processed: Boon Lay (East)_2012_08
# Downloaded and processed: Boon Lay (East)_2012_09
# Downloaded and processed: Boon Lay (East)_2012_10
# Downloaded and processed: Boon Lay (East)_2012_11
# Downloaded and processed: Boon Lay (East)_2012_12
# Downloaded and processed: Boon Lay (East)_2013_01
# Downloaded and processed: Boon Lay (East)_2013_02
# Downloaded and processed: Boon Lay (East)_2013_03
# Downloaded and processed: Boon Lay (East)_2013_04
# Downloaded and processed: Boon Lay (East)_2013_05
# Downloaded and processed: Boon Lay (East)_2013_06
# Downloaded and processed: Boon Lay (East)_2013_07
# Downloaded and processed: Boon Lay (East)_2013_08
# Downloaded and processed: Boon Lay (East)_2013_09
# Downloaded and processed: Boon Lay (East)_2013_10
# Downloaded and processed: Boon Lay (East)_2013_11
# Downloaded and processed: Boon Lay (East)_2013_12
# Downloaded and processed: Boon Lay (East)_2014_01
# Downloaded and processed: Boon Lay (East)_2014_02
# Downloaded and processed: Boon Lay (East)_2014_03
# Downloaded and processed: Boon Lay (East)_2014_04
# Downloaded and processed: Boon Lay (East)_2014_05
# Downloaded and processed: Boon Lay (East)_2014_06
# Downloaded and processed: Boon Lay (East)_2014_07
# Downloaded and processed: Boon Lay (East)_2014_08
# Downloaded and processed: Boon Lay (East)_2014_09
# Downloaded and processed: Boon Lay (East)_2014_10
# Downloaded and processed: Boon Lay (East)_2014_11
# Downloaded and processed: Boon Lay (East)_2014_12
# Downloaded and processed: Boon Lay (East)_2015_01
# Downloaded and processed: Boon Lay (East)_2015_02
# Downloaded and processed: Boon Lay (East)_2015_03
# Downloaded and processed: Boon Lay (East)_2015_04
# Downloaded and processed: Boon Lay (East)_2015_05
# Downloaded and processed: Boon Lay (East)_2015_06
# Downloaded and processed: Boon Lay (East)_2015_07
# Downloaded and processed: Boon Lay (East)_2015_08
# Downloaded and processed: Boon Lay (East)_2015_09
# Downloaded and processed: Boon Lay (East)_2015_10
# Downloaded and processed: Boon Lay (East)_2015_11
# Downloaded and processed: Boon Lay (East)_2015_12
# Downloaded and processed: Boon Lay (East)_2016_01
# Failed to download: outputcsv_files/S86_2016_02.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_03.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_04.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_05.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_06.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_07.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_08.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_09.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_10.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_11.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2016_12.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_01.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_02.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_03.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_04.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_05.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_06.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_07.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_08.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_09.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_10.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_11.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2017_12.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_01.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_02.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_03.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_04.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_05.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_06.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_07.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_08.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_09.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_10.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_11.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2018_12.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_01.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_02.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_03.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_04.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_05.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_06.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_07.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_08.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_09.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_10.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_11.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2019_12.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_01.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_02.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_03.csv. Status code: 404
# Downloaded and processed: Boon Lay (East)_2020_04
# Failed to download: outputcsv_files/S86_2020_05.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_06.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_07.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_08.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_09.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_10.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_11.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2020_12.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_01.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_02.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_03.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_04.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_05.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_06.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_07.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_08.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_09.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_10.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_11.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2021_12.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_01.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_02.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_03.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_04.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_05.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_06.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_07.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_08.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_09.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_10.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2022_11.csv. Status code: 404
# Downloaded and processed: Boon Lay (East)_2022_12
# Failed to download: outputcsv_files/S86_2023_01.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_02.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_03.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_04.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_05.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_06.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_07.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_08.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_09.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_10.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_11.csv. Status code: 404
# Failed to download: outputcsv_files/S86_2023_12.csv. Status code: 404
# Downloaded and processed: Boon Lay (West)_2010_01
# Downloaded and processed: Boon Lay (West)_2010_02
# Downloaded and processed: Boon Lay (West)_2010_03
# Downloaded and processed: Boon Lay (West)_2010_04
# Downloaded and processed: Boon Lay (West)_2010_05
# Downloaded and processed: Boon Lay (West)_2010_06
# Downloaded and processed: Boon Lay (West)_2010_07
# Downloaded and processed: Boon Lay (West)_2010_08
# Downloaded and processed: Boon Lay (West)_2010_09
# Downloaded and processed: Boon Lay (West)_2010_10
# Downloaded and processed: Boon Lay (West)_2010_11
# Downloaded and processed: Boon Lay (West)_2010_12
# Downloaded and processed: Boon Lay (West)_2011_01
# Downloaded and processed: Boon Lay (West)_2011_02
# Downloaded and processed: Boon Lay (West)_2011_03
# Downloaded and processed: Boon Lay (West)_2011_04
# Downloaded and processed: Boon Lay (West)_2011_05
# Downloaded and processed: Boon Lay (West)_2011_06
# Downloaded and processed: Boon Lay (West)_2011_07
# Downloaded and processed: Boon Lay (West)_2011_08
# Downloaded and processed: Boon Lay (West)_2011_09
# Downloaded and processed: Boon Lay (West)_2011_10
# Downloaded and processed: Boon Lay (West)_2011_11
# Downloaded and processed: Boon Lay (West)_2011_12
# Downloaded and processed: Boon Lay (West)_2012_01
# Downloaded and processed: Boon Lay (West)_2012_02
# Downloaded and processed: Boon Lay (West)_2012_03
# Downloaded and processed: Boon Lay (West)_2012_04
# Downloaded and processed: Boon Lay (West)_2012_05
# Downloaded and processed: Boon Lay (West)_2012_06
# Downloaded and processed: Boon Lay (West)_2012_07
# Downloaded and processed: Boon Lay (West)_2012_08
# Downloaded and processed: Boon Lay (West)_2012_09
# Downloaded and processed: Boon Lay (West)_2012_10
# Downloaded and processed: Boon Lay (West)_2012_11
# Downloaded and processed: Boon Lay (West)_2012_12
# Downloaded and processed: Boon Lay (West)_2013_01
# Downloaded and processed: Boon Lay (West)_2013_02
# Downloaded and processed: Boon Lay (West)_2013_03
# Downloaded and processed: Boon Lay (West)_2013_04
# Downloaded and processed: Boon Lay (West)_2013_05
# Downloaded and processed: Boon Lay (West)_2013_06
# Downloaded and processed: Boon Lay (West)_2013_07
# Downloaded and processed: Boon Lay (West)_2013_08
# Downloaded and processed: Boon Lay (West)_2013_09
# Downloaded and processed: Boon Lay (West)_2013_10
# Downloaded and processed: Boon Lay (West)_2013_11
# Downloaded and processed: Boon Lay (West)_2013_12
# Downloaded and processed: Boon Lay (West)_2014_01
# Downloaded and processed: Boon Lay (West)_2014_02
# Downloaded and processed: Boon Lay (West)_2014_03
# Downloaded and processed: Boon Lay (West)_2014_04
# Downloaded and processed: Boon Lay (West)_2014_05
# Downloaded and processed: Boon Lay (West)_2014_06
# Downloaded and processed: Boon Lay (West)_2014_07
# Downloaded and processed: Boon Lay (West)_2014_08
# Downloaded and processed: Boon Lay (West)_2014_09
# Downloaded and processed: Boon Lay (West)_2014_10
# Downloaded and processed: Boon Lay (West)_2014_11
# Downloaded and processed: Boon Lay (West)_2014_12
# Downloaded and processed: Boon Lay (West)_2015_01
# Downloaded and processed: Boon Lay (West)_2015_02
# Downloaded and processed: Boon Lay (West)_2015_03
# Downloaded and processed: Boon Lay (West)_2015_04
# Downloaded and processed: Boon Lay (West)_2015_05
# Downloaded and processed: Boon Lay (West)_2015_06
# Downloaded and processed: Boon Lay (West)_2015_07
# Downloaded and processed: Boon Lay (West)_2015_08
# Downloaded and processed: Boon Lay (West)_2015_09
# Downloaded and processed: Boon Lay (West)_2015_10
# Downloaded and processed: Boon Lay (West)_2015_11
# Downloaded and processed: Boon Lay (West)_2015_12
# Downloaded and processed: Boon Lay (West)_2016_01
# Downloaded and processed: Boon Lay (West)_2016_02
# Downloaded and processed: Boon Lay (West)_2016_03
# Downloaded and processed: Boon Lay (West)_2016_04
# Downloaded and processed: Boon Lay (West)_2016_05
# Downloaded and processed: Boon Lay (West)_2016_06
# Downloaded and processed: Boon Lay (West)_2016_07
# Downloaded and processed: Boon Lay (West)_2016_08
# Downloaded and processed: Boon Lay (West)_2016_09
# Downloaded and processed: Boon Lay (West)_2016_10
# Downloaded and processed: Boon Lay (West)_2016_11
# Downloaded and processed: Boon Lay (West)_2016_12
# Downloaded and processed: Boon Lay (West)_2017_01
# Downloaded and processed: Boon Lay (West)_2017_02
# Downloaded and processed: Boon Lay (West)_2017_03
# Downloaded and processed: Boon Lay (West)_2017_04
# Downloaded and processed: Boon Lay (West)_2017_05
# Downloaded and processed: Boon Lay (West)_2017_06
# Downloaded and processed: Boon Lay (West)_2017_07
# Downloaded and processed: Boon Lay (West)_2017_08
# Downloaded and processed: Boon Lay (West)_2017_09
# Downloaded and processed: Boon Lay (West)_2017_10
# Downloaded and processed: Boon Lay (West)_2017_11
# Downloaded and processed: Boon Lay (West)_2017_12
# Downloaded and processed: Boon Lay (West)_2018_01
# Downloaded and processed: Boon Lay (West)_2018_02
# Failed to download: outputcsv_files/S63_2018_03.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2018_04.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2018_05.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2018_06.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2018_07.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2018_08.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2018_09.csv. Status code: 404
# Downloaded and processed: Boon Lay (West)_2018_10
# Failed to download: outputcsv_files/S63_2018_11.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2018_12.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_01.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_02.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_03.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_04.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_05.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_06.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_07.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_08.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_09.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_10.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_11.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2019_12.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_01.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_02.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_03.csv. Status code: 404
# Downloaded and processed: Boon Lay (West)_2020_04
# Failed to download: outputcsv_files/S63_2020_05.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_06.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_07.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_08.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_09.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_10.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_11.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2020_12.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_01.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_02.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_03.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_04.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_05.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_06.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_07.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_08.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_09.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_10.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_11.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2021_12.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_01.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_02.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_03.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_04.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_05.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_06.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_07.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_08.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_09.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_10.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_11.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2022_12.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_01.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_02.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_03.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_04.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_05.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_06.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_07.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_08.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_09.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_10.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_11.csv. Status code: 404
# Failed to download: outputcsv_files/S63_2023_12.csv. Status code: 404
# Failed to download: outputcsv_files/S120_2010_01.csv. Status code: 404
# Failed to download: outputcsv_files/S120_2010_02.csv. Status code: 404
# Failed to download: outputcsv_files/S120_2010_03.csv. Status code: 404
# Failed to download: outputcsv_files/S120_2010_04.csv. Status code: 404
# Failed to download: outputcsv_files/S120_2010_05.csv. Status code: 404
# Failed to download: outputcsv_files/S120_2010_06.csv. Status code: 404
# Failed to download: outputcsv_files/S120_2010_07.csv. Status code: 404
# Failed to download: outputcsv_files/S120_2010_08.csv. Status code: 404
# Downloaded and processed: Botanic Garden_2010_09
# Downloaded and processed: Botanic Garden_2010_10
# Downloaded and processed: Botanic Garden_2010_11
# Downloaded and processed: Botanic Garden_2010_12
# Downloaded and processed: Botanic Garden_2011_01
# Downloaded and processed: Botanic Garden_2011_02
# Downloaded and processed: Botanic Garden_2011_03
# Downloaded and processed: Botanic Garden_2011_04
# Downloaded and processed: Botanic Garden_2011_05
# Downloaded and processed: Botanic Garden_2011_06
# Downloaded and processed: Botanic Garden_2011_07
# Downloaded and processed: Botanic Garden_2011_08
# Downloaded and processed: Botanic Garden_2011_09
# Downloaded and processed: Botanic Garden_2011_10
# Downloaded and processed: Botanic Garden_2011_11
# Downloaded and processed: Botanic Garden_2011_12
# Downloaded and processed: Botanic Garden_2012_01
# Downloaded and processed: Botanic Garden_2012_02
# Downloaded and processed: Botanic Garden_2012_03
# Downloaded and processed: Botanic Garden_2012_04
# Downloaded and processed: Botanic Garden_2012_05
# Downloaded and processed: Botanic Garden_2012_06
# Downloaded and processed: Botanic Garden_2012_07
# Downloaded and processed: Botanic Garden_2012_08
# Downloaded and processed: Botanic Garden_2012_09
# Downloaded and processed: Botanic Garden_2012_10
# Downloaded and processed: Botanic Garden_2012_11
# Downloaded and processed: Botanic Garden_2012_12
# Downloaded and processed: Botanic Garden_2013_01
# Downloaded and processed: Botanic Garden_2013_02
# Downloaded and processed: Botanic Garden_2013_03
# Downloaded and processed: Botanic Garden_2013_04
# Downloaded and processed: Botanic Garden_2013_05
# Downloaded and processed: Botanic Garden_2013_06
# Downloaded and processed: Botanic Garden_2013_07
# Downloaded and processed: Botanic Garden_2013_08
# Downloaded and processed: Botanic Garden_2013_09
# Downloaded and processed: Botanic Garden_2013_10
# Downloaded and processed: Botanic Garden_2013_11
# Downloaded and processed: Botanic Garden_2013_12
# Downloaded and processed: Botanic Garden_2014_01
# Downloaded and processed: Botanic Garden_2014_02
# Downloaded and processed: Botanic Garden_2014_03
# Downloaded and processed: Botanic Garden_2014_04
# Downloaded and processed: Botanic Garden_2014_05
# Downloaded and processed: Botanic Garden_2014_06
# Downloaded and processed: Botanic Garden_2014_07
# Downloaded and processed: Botanic Garden_2014_08
# Downloaded and processed: Botanic Garden_2014_09
# Downloaded and processed: Botanic Garden_2014_10
# Downloaded and processed: Botanic Garden_2014_11
# Downloaded and processed: Botanic Garden_2014_12
# ...
# Failed to download: outputcsv_files/S46_2023_10.csv. Status code: 404
# Failed to download: outputcsv_files/S46_2023_11.csv. Status code: 404
# Failed to download: outputcsv_files/S46_2023_12.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_01.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_02.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_03.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_04.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_05.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_06.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_07.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_08.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_09.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_10.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_11.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2010_12.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_01.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_02.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_03.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_04.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_05.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_06.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_07.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_08.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2011_09.csv. Status code: 404
# Downloaded and processed: Whampoa_2011_10
# Downloaded and processed: Whampoa_2011_11
# Downloaded and processed: Whampoa_2011_12
# Downloaded and processed: Whampoa_2012_01
# Downloaded and processed: Whampoa_2012_02
# Downloaded and processed: Whampoa_2012_03
# Downloaded and processed: Whampoa_2012_04
# Downloaded and processed: Whampoa_2012_05
# Downloaded and processed: Whampoa_2012_06
# Downloaded and processed: Whampoa_2012_07
# Downloaded and processed: Whampoa_2012_08
# Downloaded and processed: Whampoa_2012_09
# Downloaded and processed: Whampoa_2012_10
# Downloaded and processed: Whampoa_2012_11
# Downloaded and processed: Whampoa_2012_12
# Downloaded and processed: Whampoa_2013_01
# Downloaded and processed: Whampoa_2013_02
# Downloaded and processed: Whampoa_2013_03
# Downloaded and processed: Whampoa_2013_04
# Downloaded and processed: Whampoa_2013_05
# Downloaded and processed: Whampoa_2013_06
# Downloaded and processed: Whampoa_2013_07
# Downloaded and processed: Whampoa_2013_08
# Downloaded and processed: Whampoa_2013_09
# Downloaded and processed: Whampoa_2013_10
# Downloaded and processed: Whampoa_2013_11
# Downloaded and processed: Whampoa_2013_12
# Downloaded and processed: Whampoa_2014_01
# Downloaded and processed: Whampoa_2014_02
# Downloaded and processed: Whampoa_2014_03
# Downloaded and processed: Whampoa_2014_04
# Downloaded and processed: Whampoa_2014_05
# Downloaded and processed: Whampoa_2014_06
# Downloaded and processed: Whampoa_2014_07
# Downloaded and processed: Whampoa_2014_08
# Downloaded and processed: Whampoa_2014_09
# Downloaded and processed: Whampoa_2014_10
# Downloaded and processed: Whampoa_2014_11
# Downloaded and processed: Whampoa_2014_12
# Downloaded and processed: Whampoa_2015_01
# Downloaded and processed: Whampoa_2015_02
# Downloaded and processed: Whampoa_2015_03
# Downloaded and processed: Whampoa_2015_04
# Downloaded and processed: Whampoa_2015_05
# Downloaded and processed: Whampoa_2015_06
# Downloaded and processed: Whampoa_2015_07
# Downloaded and processed: Whampoa_2015_08
# Downloaded and processed: Whampoa_2015_09
# Downloaded and processed: Whampoa_2015_10
# Downloaded and processed: Whampoa_2015_11
# Downloaded and processed: Whampoa_2015_12
# Downloaded and processed: Whampoa_2016_01
# Downloaded and processed: Whampoa_2016_02
# Downloaded and processed: Whampoa_2016_03
# Downloaded and processed: Whampoa_2016_04
# Downloaded and processed: Whampoa_2016_05
# Downloaded and processed: Whampoa_2016_06
# Downloaded and processed: Whampoa_2016_07
# Downloaded and processed: Whampoa_2016_08
# Downloaded and processed: Whampoa_2016_09
# Downloaded and processed: Whampoa_2016_10
# Downloaded and processed: Whampoa_2016_11
# Downloaded and processed: Whampoa_2016_12
# Downloaded and processed: Whampoa_2017_01
# Downloaded and processed: Whampoa_2017_02
# Downloaded and processed: Whampoa_2017_03
# Downloaded and processed: Whampoa_2017_04
# Downloaded and processed: Whampoa_2017_05
# Downloaded and processed: Whampoa_2017_06
# Downloaded and processed: Whampoa_2017_07
# Downloaded and processed: Whampoa_2017_08
# Downloaded and processed: Whampoa_2017_09
# Downloaded and processed: Whampoa_2017_10
# Downloaded and processed: Whampoa_2017_11
# Downloaded and processed: Whampoa_2017_12
# Downloaded and processed: Whampoa_2018_01
# Downloaded and processed: Whampoa_2018_02
# Downloaded and processed: Whampoa_2018_03
# Downloaded and processed: Whampoa_2018_04
# Downloaded and processed: Whampoa_2018_05
# Downloaded and processed: Whampoa_2018_06
# Downloaded and processed: Whampoa_2018_07
# Downloaded and processed: Whampoa_2018_08
# Downloaded and processed: Whampoa_2018_09
# Downloaded and processed: Whampoa_2018_10
# Downloaded and processed: Whampoa_2018_11
# Downloaded and processed: Whampoa_2018_12
# Downloaded and processed: Whampoa_2019_01
# Downloaded and processed: Whampoa_2019_02
# Downloaded and processed: Whampoa_2019_03
# Downloaded and processed: Whampoa_2019_04
# Downloaded and processed: Whampoa_2019_05
# Downloaded and processed: Whampoa_2019_06
# Downloaded and processed: Whampoa_2019_07
# Downloaded and processed: Whampoa_2019_08
# Downloaded and processed: Whampoa_2019_09
# Downloaded and processed: Whampoa_2019_10
# Downloaded and processed: Whampoa_2019_11
# Downloaded and processed: Whampoa_2019_12
# Downloaded and processed: Whampoa_2020_01
# Downloaded and processed: Whampoa_2020_02
# Downloaded and processed: Whampoa_2020_03
# Downloaded and processed: Whampoa_2020_04
# Downloaded and processed: Whampoa_2020_05
# Downloaded and processed: Whampoa_2020_06
# Downloaded and processed: Whampoa_2020_07
# Downloaded and processed: Whampoa_2020_08
# Downloaded and processed: Whampoa_2020_09
# Downloaded and processed: Whampoa_2020_10
# Downloaded and processed: Whampoa_2020_11
# Downloaded and processed: Whampoa_2020_12
# Downloaded and processed: Whampoa_2021_01
# Downloaded and processed: Whampoa_2021_02
# Downloaded and processed: Whampoa_2021_03
# Downloaded and processed: Whampoa_2021_04
# Downloaded and processed: Whampoa_2021_05
# Downloaded and processed: Whampoa_2021_06
# Downloaded and processed: Whampoa_2021_07
# Downloaded and processed: Whampoa_2021_08
# Downloaded and processed: Whampoa_2021_09
# Downloaded and processed: Whampoa_2021_10
# Downloaded and processed: Whampoa_2021_11
# Downloaded and processed: Whampoa_2021_12
# Downloaded and processed: Whampoa_2022_01
# Downloaded and processed: Whampoa_2022_02
# Downloaded and processed: Whampoa_2022_03
# Downloaded and processed: Whampoa_2022_04
# Downloaded and processed: Whampoa_2022_05
# Downloaded and processed: Whampoa_2022_06
# Downloaded and processed: Whampoa_2022_07
# Downloaded and processed: Whampoa_2022_08
# Downloaded and processed: Whampoa_2022_09
# Downloaded and processed: Whampoa_2022_10
# Downloaded and processed: Whampoa_2022_11
# Downloaded and processed: Whampoa_2022_12
# Downloaded and processed: Whampoa_2023_01
# Downloaded and processed: Whampoa_2023_02
# Downloaded and processed: Whampoa_2023_03
# Downloaded and processed: Whampoa_2023_04
# Downloaded and processed: Whampoa_2023_05
# Downloaded and processed: Whampoa_2023_06
# Downloaded and processed: Whampoa_2023_07
# Failed to download: outputcsv_files/S123_2023_08.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2023_09.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2023_10.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2023_11.csv. Status code: 404
# Failed to download: outputcsv_files/S123_2023_12.csv. Status code: 404
# Downloaded and processed: Yishun_2010_01
# Downloaded and processed: Yishun_2010_02
# Downloaded and processed: Yishun_2010_03
# Downloaded and processed: Yishun_2010_04
# Downloaded and processed: Yishun_2010_05
# Downloaded and processed: Yishun_2010_06
# Downloaded and processed: Yishun_2010_07
# Downloaded and processed: Yishun_2010_08
# Downloaded and processed: Yishun_2010_09
# Downloaded and processed: Yishun_2010_10
# Downloaded and processed: Yishun_2010_11
# Downloaded and processed: Yishun_2010_12
# Downloaded and processed: Yishun_2011_01
# Downloaded and processed: Yishun_2011_02
# Downloaded and processed: Yishun_2011_03
# Downloaded and processed: Yishun_2011_04
# Downloaded and processed: Yishun_2011_05
# Downloaded and processed: Yishun_2011_06
# Downloaded and processed: Yishun_2011_07
# Downloaded and processed: Yishun_2011_08
# Downloaded and processed: Yishun_2011_09
# Downloaded and processed: Yishun_2011_10
# Downloaded and processed: Yishun_2011_11
# Downloaded and processed: Yishun_2011_12
# Downloaded and processed: Yishun_2012_01
# Downloaded and processed: Yishun_2012_02
# Downloaded and processed: Yishun_2012_03
# Failed to download: outputcsv_files/S91_2012_04.csv. Status code: 404
# Downloaded and processed: Yishun_2012_05
# Downloaded and processed: Yishun_2012_06
# Downloaded and processed: Yishun_2012_07
# Downloaded and processed: Yishun_2012_08
# Downloaded and processed: Yishun_2012_09
# Downloaded and processed: Yishun_2012_10
# Downloaded and processed: Yishun_2012_11
# Downloaded and processed: Yishun_2012_12
# Downloaded and processed: Yishun_2013_01
# Downloaded and processed: Yishun_2013_02
# Downloaded and processed: Yishun_2013_03
# Downloaded and processed: Yishun_2013_04
# Downloaded and processed: Yishun_2013_05
# Downloaded and processed: Yishun_2013_06
# Downloaded and processed: Yishun_2013_07
# Downloaded and processed: Yishun_2013_08
# Downloaded and processed: Yishun_2013_09
# Downloaded and processed: Yishun_2013_10
# Downloaded and processed: Yishun_2013_11
# Failed to download: outputcsv_files/S91_2013_12.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2014_01.csv. Status code: 404
# Downloaded and processed: Yishun_2014_02
# Downloaded and processed: Yishun_2014_03
# Downloaded and processed: Yishun_2014_04
# Downloaded and processed: Yishun_2014_05
# Downloaded and processed: Yishun_2014_06
# Downloaded and processed: Yishun_2014_07
# Downloaded and processed: Yishun_2014_08
# Downloaded and processed: Yishun_2014_09
# Downloaded and processed: Yishun_2014_10
# Downloaded and processed: Yishun_2014_11
# Downloaded and processed: Yishun_2014_12
# Downloaded and processed: Yishun_2015_01
# Downloaded and processed: Yishun_2015_02
# Downloaded and processed: Yishun_2015_03
# Downloaded and processed: Yishun_2015_04
# Downloaded and processed: Yishun_2015_05
# Downloaded and processed: Yishun_2015_06
# Downloaded and processed: Yishun_2015_07
# Downloaded and processed: Yishun_2015_08
# Downloaded and processed: Yishun_2015_09
# Downloaded and processed: Yishun_2015_10
# Downloaded and processed: Yishun_2015_11
# Downloaded and processed: Yishun_2015_12
# Downloaded and processed: Yishun_2016_01
# Downloaded and processed: Yishun_2016_02
# Downloaded and processed: Yishun_2016_03
# Downloaded and processed: Yishun_2016_04
# Downloaded and processed: Yishun_2016_05
# Downloaded and processed: Yishun_2016_06
# Downloaded and processed: Yishun_2016_07
# Downloaded and processed: Yishun_2016_08
# Downloaded and processed: Yishun_2016_09
# Downloaded and processed: Yishun_2016_10
# Downloaded and processed: Yishun_2016_11
# Downloaded and processed: Yishun_2016_12
# Downloaded and processed: Yishun_2017_01
# Downloaded and processed: Yishun_2017_02
# Downloaded and processed: Yishun_2017_03
# Downloaded and processed: Yishun_2017_04
# Downloaded and processed: Yishun_2017_05
# Downloaded and processed: Yishun_2017_06
# Downloaded and processed: Yishun_2017_07
# Downloaded and processed: Yishun_2017_08
# Downloaded and processed: Yishun_2017_09
# Downloaded and processed: Yishun_2017_10
# Downloaded and processed: Yishun_2017_11
# Downloaded and processed: Yishun_2017_12
# Downloaded and processed: Yishun_2018_01
# Downloaded and processed: Yishun_2018_02
# Downloaded and processed: Yishun_2018_03
# Downloaded and processed: Yishun_2018_04
# Downloaded and processed: Yishun_2018_05
# Downloaded and processed: Yishun_2018_06
# Downloaded and processed: Yishun_2018_07
# Downloaded and processed: Yishun_2018_08
# Downloaded and processed: Yishun_2018_09
# Downloaded and processed: Yishun_2018_10
# Downloaded and processed: Yishun_2018_11
# Downloaded and processed: Yishun_2018_12
# Downloaded and processed: Yishun_2019_01
# Downloaded and processed: Yishun_2019_02
# Downloaded and processed: Yishun_2019_03
# Downloaded and processed: Yishun_2019_04
# Downloaded and processed: Yishun_2019_05
# Downloaded and processed: Yishun_2019_06
# Downloaded and processed: Yishun_2019_07
# Downloaded and processed: Yishun_2019_08
# Downloaded and processed: Yishun_2019_09
# Downloaded and processed: Yishun_2019_10
# Downloaded and processed: Yishun_2019_11
# Downloaded and processed: Yishun_2019_12
# Downloaded and processed: Yishun_2020_01
# Downloaded and processed: Yishun_2020_02
# Downloaded and processed: Yishun_2020_03
# Downloaded and processed: Yishun_2020_04
# Downloaded and processed: Yishun_2020_05
# Downloaded and processed: Yishun_2020_06
# Downloaded and processed: Yishun_2020_07
# Downloaded and processed: Yishun_2020_08
# Downloaded and processed: Yishun_2020_09
# Downloaded and processed: Yishun_2020_10
# Downloaded and processed: Yishun_2020_11
# Downloaded and processed: Yishun_2020_12
# Downloaded and processed: Yishun_2021_01
# Downloaded and processed: Yishun_2021_02
# Downloaded and processed: Yishun_2021_03
# Downloaded and processed: Yishun_2021_04
# Failed to download: outputcsv_files/S91_2021_05.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2021_06.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2021_07.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2021_08.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2021_09.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2021_10.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2021_11.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2021_12.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_01.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_02.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_03.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_04.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_05.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_06.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_07.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_08.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_09.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_10.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_11.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2022_12.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_01.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_02.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_03.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_04.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_05.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_06.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_07.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_08.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_09.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_10.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_11.csv. Status code: 404
# Failed to download: outputcsv_files/S91_2023_12.csv. Status code: 404
# Combined data saved to 'outputcsv_files/combined_data.csv'.
